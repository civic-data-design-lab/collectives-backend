# %%
from twython import Twython
import json
import pandas as pd
import numpy as np

# Load credentials from json file
with open("twitter_credentials.json", "r") as file:
    creds = json.load(file)

# Instantiate an object
twitter = Twython(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'])

# Create our query
query = {'screen_name': 'dchalpern'
        }

# %%
text_block = ""
followers_list = ['mitsap','ArchDaily','designboom','la_Biennale','MITarchitecture']
for index, follower in enumerate(followers_list):
    print(follower)
    returned = twitter.get(endpoint='https://api.twitter.com/1.1/statuses/user_timeline.json', params={'screen_name':follower,'count':500, 'exclude_replies':True, 'include_rts':False})
    print(len(returned))
    print(len(text_block))
    if (index==0):
        tweets_df = pd.DataFrame(returned)
        tweets_df['user'] = follower
    else:
        temp_df = pd.DataFrame(returned)
        temp_df['user'] = follower
        tweets_df = tweets_df.append(temp_df)
# Out:
# mitsap
# 102
# 0
# ArchDaily
# 200
# 0
# designboom
# 200
# 0
# la_Biennale
# 186
# 0
# MITarchitecture
# 60
# 0

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

# %%
count_vect = CountVectorizer(max_df=0.8, min_df=2, stop_words='english')
doc_term_matrix = count_vect.fit_transform(tweets_df['text'].values.astype('U'))

# %%
doc_term_matrix
# Out:
# <748x1194 sparse matrix of type '<class 'numpy.int64'>'
# 	with 4376 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import LatentDirichletAllocation

LDA = LatentDirichletAllocation(n_components=10, random_state=42)
LDA.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=10, n_jobs=None,
#                           perp_tol=0.1, random_state=42, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %%
import random

for i in range(10):
    random_id = random.randint(0,len(count_vect.get_feature_names()))
    print(count_vect.get_feature_names()[random_id])
    
first_topic = LDA.components_[0]
# Out:
# coast
# explo
# material
# forms
# 2br0aju4po
# conceptualize
# encloses
# norway
# ve
# diving

# %%
top_topic_words = first_topic.argsort()[-10:]
print(top_topic_words)
for i in top_topic_words:
    print(count_vect.get_feature_names()[i])
for i,topic in enumerate(LDA.components_):
    print(f'Top 10 words for topic #{i}:')
    print([count_vect.get_feature_names()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# [ 339  108  526 1021  530  926  507  152   96  527]
# designs
# arquitetos
# hotel
# studio
# howwillwelivetogether
# sarkis
# hashim
# biennalearchitettura2020
# architects
# house
# Top 10 words for topic #0:
# ['designs', 'arquitetos', 'hotel', 'studio', 'howwillwelivetogether', 'sarkis', 'hashim', 'biennalearchitettura2020', 'architects', 'house']
#
#
# Top 10 words for topic #1:
# ['da', 'materials', 'view', 'ca', 'giustinian', 'la', 'thesis', 'projects', 'biennalecarnevale2020', 'il']
#
#
# Top 10 words for topic #2:
# ['unveils', 'architects', 'building', 'community', 'events', 'weekly', 'resources', 'news', 'sa', 'school']
#
#
# Top 10 words for topic #3:
# ['urban', 'year', 'joker', 'center', 'research', 'cabin', 'designs', 'architecture', 'venezia76', 'biennalecinema2019']
#
#
# Top 10 words for topic #4:
# ['biennalearchitettura2020', 'menzione', 'pritzker', '2020', 'speciale', 'paolo', 'di', 'baratta', 'biennalecarnevale2020', 'il']
#
#
# Top 10 words for topic #5:
# ['like', 'venice', 'builds', 'hand', 'rural', 'store', 'center', 'studio', 'howwillwelivetogether', 'biennalearchitettura2020']
#
#
# Top 10 words for topic #6:
# ['bcho', 'use', 'studio', 'discuss', 'design', 'concrete', 'architects', 'china', 'architecture', 'city']
#
#
# Top 10 words for topic #7:
# ['2020', 'open', 'amp', 'digital', 'air', 'casa', 'museum', 'design', 'new', 'architecture']
#
#
# Top 10 words for topic #8:
# ['10', 'leone', 'creatività', 'argento', 'biennalecarnevale2020', 'designs', 'new', 'la', 'il', 'office']
#
#
# Top 10 words for topic #9:
# ['arquitectos', 'green', 'al', 'le', 'venezia', 'architecture', 'della', 'house', 'di', 'la']

# %%
topic_values = LDA.transform(doc_term_matrix)
topic_values.shape
tweets_df['Topic'] = topic_values.argmax(axis=1)
tweets_df.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Mon Jan 13 17:45:08 +0000 2020  1216778219636039681  1216778219636039681
# 1  Sat Jan 11 15:45:05 +0000 2020  1216023230575775746  1216023230575775746
# 2  Fri Jan 10 18:40:04 +0000 2020  1215704880708538369  1215704880708538369
# 3  Thu Jan 09 01:17:07 +0000 2020  1215080026116427776  1215080026116427776
# 4  Fri Dec 06 16:35:05 +0000 2019  1202989850351296512  1202989850351296512
#
#                                                 text  truncated  \
# 0    https://t.co/Q7WSVmasnc https://t.co/iMCbG2VfXk      False
# 1    https://t.co/cGodXM8ZJS https://t.co/lHXPIEbKZa      False
# 2    https://t.co/fWGtG511P5 https://t.co/mJhbtITBwT      False
# 3  Want to get rid of vacant storefronts? Let art...       True
# 4                            https://t.co/humao71IWM      False
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                    extended_entities  \
# 0  {'media': [{'id': 1216778217694121984, 'id_str...
# 1  {'media': [{'id': 1216023228684099584, 'id_str...
# 2  {'media': [{'id': 1215704879064322049, 'id_str...
# 3                                                NaN
# 4                                                NaN
#
#                                               source in_reply_to_status_id  \
# 0  <a href="https://www.hootsuite.com" rel="nofol...                  None
# 1  <a href="https://www.hootsuite.com" rel="nofol...                  None
# 2  <a href="https://www.hootsuite.com" rel="nofol...                  None
# 3  <a href="https://www.hootsuite.com" rel="nofol...                  None
# 4  <a href="https://www.hootsuite.com" rel="nofol...                  None
#
#   in_reply_to_status_id_str  ... quoted_status_id quoted_status_id_str  \
# 0                      None  ...     1.214944e+18  1214943608928759809
# 1                      None  ...     1.214982e+18  1214982058818166785
# 2                      None  ...     1.215315e+18  1215315067438170112
# 3                      None  ...              NaN                  NaN
# 4                      None  ...     1.202021e+18  1202020693988249602
#
#                                        quoted_status retweet_count  \
# 0  {'created_at': 'Wed Jan 08 16:15:03 +0000 2020...             2
# 1  {'created_at': 'Wed Jan 08 18:47:50 +0000 2020...             0
# 2  {'created_at': 'Thu Jan 09 16:51:06 +0000 2020...             0
# 3                                                NaN             1
# 4  {'created_at': 'Wed Dec 04 00:24:00 +0000 2019...             0
#
#   favorite_count favorited retweeted possibly_sensitive  lang  Topic
# 0              5     False     False              False   und      0
# 1              6     False     False              False   und      0
# 2              5     False     False              False   und      0
# 3              7     False     False              False    en      2
# 4              2     False     False              False   und      0
#
# [5 rows x 29 columns]

# %%
tweets_df.head(20)
# Out:
#                         created_at                   id               id_str  \
# 0   Mon Jan 13 17:45:08 +0000 2020  1216778219636039681  1216778219636039681
# 1   Sat Jan 11 15:45:05 +0000 2020  1216023230575775746  1216023230575775746
# 2   Fri Jan 10 18:40:04 +0000 2020  1215704880708538369  1215704880708538369
# 3   Thu Jan 09 01:17:07 +0000 2020  1215080026116427776  1215080026116427776
# 4   Fri Dec 06 16:35:05 +0000 2019  1202989850351296512  1202989850351296512
# 5   Thu Dec 05 17:30:17 +0000 2019  1202641353240387584  1202641353240387584
# 6   Thu Dec 05 15:22:39 +0000 2019  1202609236146053120  1202609236146053120
# 7   Mon Dec 02 20:25:03 +0000 2019  1201598171308269572  1201598171308269572
# 8   Mon Dec 02 15:46:07 +0000 2019  1201527976971640843  1201527976971640843
# 9   Mon Nov 25 16:15:07 +0000 2019  1198998560982929408  1198998560982929408
# 10  Sun Nov 24 17:50:03 +0000 2019  1198660061528305664  1198660061528305664
# 11  Sat Nov 23 18:35:03 +0000 2019  1198309000976224257  1198309000976224257
# 12  Sat Nov 23 16:50:04 +0000 2019  1198282577645309957  1198282577645309957
# 13  Fri Nov 22 19:45:07 +0000 2019  1197964242432995328  1197964242432995328
# 14  Fri Nov 22 17:15:13 +0000 2019  1197926519244558337  1197926519244558337
# 15  Thu Nov 21 18:45:06 +0000 2019  1197586753063964673  1197586753063964673
# 16  Thu Nov 21 16:45:08 +0000 2019  1197556560232419329  1197556560232419329
# 17  Tue Nov 19 18:15:08 +0000 2019  1196854436167081985  1196854436167081985
# 18  Tue Nov 19 17:46:34 +0000 2019  1196847247583010816  1196847247583010816
# 19  Mon Nov 18 15:40:05 +0000 2019  1196453026237689859  1196453026237689859
#
#                                                  text  truncated  \
# 0     https://t.co/Q7WSVmasnc https://t.co/iMCbG2VfXk      False
# 1     https://t.co/cGodXM8ZJS https://t.co/lHXPIEbKZa      False
# 2     https://t.co/fWGtG511P5 https://t.co/mJhbtITBwT      False
# 3   Want to get rid of vacant storefronts? Let art...       True
# 4                             https://t.co/humao71IWM      False
# 5                             https://t.co/FE5t3NTtjs      False
# 6             Today at 12:30! https://t.co/EnF3bhPibf      False
# 7                             https://t.co/cirmsAgADK      False
# 8   Today @ 6pm,  @ACTMIT event: Naeem Mohaiemen, ...       True
# 9                             https://t.co/ojcbJZzs0B      False
# 10                            https://t.co/PXFFDq3blz      False
# 11  Your weekly five from SA+P: News, resources, a...      False
# 12                            https://t.co/LUnI1MpJx8      False
# 13                            https://t.co/fbuVWT71aW      False
# 14                            https://t.co/EWPbmkJ9u8      False
# 15                            https://t.co/D3xuyk2CMz      False
# 16                            https://t.co/l0GPQdzrvq      False
# 17  The Collier Memorial is an @AIANational's 2019...       True
# 18                            https://t.co/1YiV4opYQ5      False
# 19                            https://t.co/SEbbzzIwp6      False
#
#                                              entities  \
# 0   {'hashtags': [], 'symbols': [], 'user_mentions...
# 1   {'hashtags': [], 'symbols': [], 'user_mentions...
# 2   {'hashtags': [], 'symbols': [], 'user_mentions...
# 3   {'hashtags': [], 'symbols': [], 'user_mentions...
# 4   {'hashtags': [], 'symbols': [], 'user_mentions...
# 5   {'hashtags': [], 'symbols': [], 'user_mentions...
# 6   {'hashtags': [], 'symbols': [], 'user_mentions...
# 7   {'hashtags': [], 'symbols': [], 'user_mentions...
# 8   {'hashtags': [], 'symbols': [], 'user_mentions...
# 9   {'hashtags': [], 'symbols': [], 'user_mentions...
# 10  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11  {'hashtags': [], 'symbols': [], 'user_mentions...
# 12  {'hashtags': [], 'symbols': [], 'user_mentions...
# 13  {'hashtags': [], 'symbols': [], 'user_mentions...
# 14  {'hashtags': [], 'symbols': [], 'user_mentions...
# 15  {'hashtags': [], 'symbols': [], 'user_mentions...
# 16  {'hashtags': [], 'symbols': [], 'user_mentions...
# 17  {'hashtags': [], 'symbols': [], 'user_mentions...
# 18  {'hashtags': [], 'symbols': [], 'user_mentions...
# 19  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                     extended_entities  \
# 0   {'media': [{'id': 1216778217694121984, 'id_str...
# 1   {'media': [{'id': 1216023228684099584, 'id_str...
# 2   {'media': [{'id': 1215704879064322049, 'id_str...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  {'media': [{'id': 1198308999160049664, 'id_str...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                                source in_reply_to_status_id  \
# 0   <a href="https://www.hootsuite.com" rel="nofol...                  None
# 1   <a href="https://www.hootsuite.com" rel="nofol...                  None
# 2   <a href="https://www.hootsuite.com" rel="nofol...                  None
# 3   <a href="https://www.hootsuite.com" rel="nofol...                  None
# 4   <a href="https://www.hootsuite.com" rel="nofol...                  None
# 5   <a href="https://www.hootsuite.com" rel="nofol...                  None
# 6   <a href="https://www.hootsuite.com" rel="nofol...                  None
# 7   <a href="https://www.hootsuite.com" rel="nofol...                  None
# 8   <a href="https://www.hootsuite.com" rel="nofol...                  None
# 9   <a href="https://www.hootsuite.com" rel="nofol...                  None
# 10  <a href="https://www.hootsuite.com" rel="nofol...                  None
# 11  <a href="https://www.hootsuite.com" rel="nofol...                  None
# 12  <a href="https://www.hootsuite.com" rel="nofol...                  None
# 13  <a href="https://www.hootsuite.com" rel="nofol...                  None
# 14  <a href="https://www.hootsuite.com" rel="nofol...                  None
# 15  <a href="https://www.hootsuite.com" rel="nofol...                  None
# 16  <a href="https://www.hootsuite.com" rel="nofol...                  None
# 17  <a href="https://www.hootsuite.com" rel="nofol...                  None
# 18  <a href="https://www.hootsuite.com" rel="nofol...                  None
# 19  <a href="https://www.hootsuite.com" rel="nofol...                  None
#
#    in_reply_to_status_id_str  ... quoted_status_id quoted_status_id_str  \
# 0                       None  ...     1.214944e+18  1214943608928759809
# 1                       None  ...     1.214982e+18  1214982058818166785
# 2                       None  ...     1.215315e+18  1215315067438170112
# 3                       None  ...              NaN                  NaN
# 4                       None  ...     1.202021e+18  1202020693988249602
# 5                       None  ...     1.202298e+18  1202298134560411650
# 6                       None  ...     1.201912e+18  1201912404306726912
# 7                       None  ...              NaN                  NaN
# 8                       None  ...              NaN                  NaN
# 9                       None  ...     1.196995e+18  1196994593989914626
# 10                      None  ...     1.196802e+18  1196802034671898625
# 11                      None  ...              NaN                  NaN
# 12                      None  ...     1.196815e+18  1196814984271073280
# 13                      None  ...     1.196870e+18  1196869756080574466
# 14                      None  ...     1.197047e+18  1197047394824859648
# 15                      None  ...     1.197201e+18  1197200765800112129
# 16                      None  ...     1.197210e+18  1197210405057236992
# 17                      None  ...              NaN                  NaN
# 18                      None  ...     1.196572e+18  1196571978045374465
# 19                      None  ...     1.195006e+18  1195005641368072192
#
#                                         quoted_status retweet_count  \
# 0   {'created_at': 'Wed Jan 08 16:15:03 +0000 2020...             2
# 1   {'created_at': 'Wed Jan 08 18:47:50 +0000 2020...             0
# 2   {'created_at': 'Thu Jan 09 16:51:06 +0000 2020...             0
# 3                                                 NaN             1
# 4   {'created_at': 'Wed Dec 04 00:24:00 +0000 2019...             0
# 5   {'created_at': 'Wed Dec 04 18:46:27 +0000 2019...             0
# 6   {'created_at': 'Tue Dec 03 17:13:42 +0000 2019...             1
# 7                                                 NaN             0
# 8                                                 NaN             0
# 9   {'created_at': 'Wed Nov 20 03:32:04 +0000 2019...             0
# 10  {'created_at': 'Tue Nov 19 14:46:55 +0000 2019...             1
# 11                                                NaN             0
# 12  {'created_at': 'Tue Nov 19 15:38:22 +0000 2019...             0
# 13  {'created_at': 'Tue Nov 19 19:16:01 +0000 2019...             0
# 14  {'created_at': 'Wed Nov 20 07:01:53 +0000 2019...             0
# 15  {'created_at': 'Wed Nov 20 17:11:20 +0000 2019...             0
# 16  {'created_at': 'Wed Nov 20 17:49:38 +0000 2019...             0
# 17                                                NaN            21
# 18  {'created_at': 'Mon Nov 18 23:32:45 +0000 2019...             0
# 19  {'created_at': 'Thu Nov 14 15:48:41 +0000 2019...             0
#
#    favorite_count favorited retweeted possibly_sensitive  lang  Topic
# 0               5     False     False              False   und      0
# 1               6     False     False              False   und      0
# 2               5     False     False              False   und      0
# 3               7     False     False              False    en      2
# 4               2     False     False              False   und      0
# 5               0     False     False              False   und      0
# 6               4     False     False              False    en      9
# 7               0     False     False              False   und      0
# 8               1     False     False              False    en      4
# 9               2     False     False              False   und      0
# 10              4     False     False              False   und      0
# 11              2     False     False              False    en      2
# 12              6     False     False              False   und      0
# 13              0     False     False              False   und      0
# 14              2     False     False              False   und      0
# 15              0     False     False              False   und      0
# 16              1     False     False              False   und      0
# 17             46     False     False              False    en      7
# 18              3     False     False              False   und      0
# 19              3     False     False              False   und      0
#
# [20 rows x 29 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vect = TfidfVectorizer(max_df=0.8, min_df=2, stop_words='english')
doc_term_matrix = tfidf_vect.fit_transform(tweets_df['text'].values.astype('U'))

# %%
from sklearn.decomposition import NMF

nmf = NMF(n_components=10, random_state=42)
nmf.fit(doc_term_matrix )
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#     n_components=10, random_state=42, shuffle=False, solver='cd', tol=0.0001,
#     verbose=0)

# %%
import random

for i in range(10):
    random_id = random.randint(0,len(tfidf_vect.get_feature_names()))
    print(tfidf_vect.get_feature_names()[random_id])
# Out:
# mao
# doors
# labotory
# details
# optical
# secondaria
# carré
# town
# effect
# rjcnj4hntt

# %%
first_topic = nmf.components_[0]
top_topic_words = first_topic.argsort()[-10:]

# %%
for i in top_topic_words:
    print(tfidf_vect.get_feature_names()[i])
# Out:
# thesis
# new
# 9o6rdm3ana
# community
# sa
# news
# resources
# events
# weekly
# school

# %%
for i,topic in enumerate(nmf.components_):
    print(f'Top 10 words for topic #{i+1}:')
    print([tfidf_vect.get_feature_names()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #1:
# ['thesis', 'new', '9o6rdm3ana', 'community', 'sa', 'news', 'resources', 'events', 'weekly', 'school']
#
#
# Top 10 words for topic #2:
# ['peter', 'rural', 'legge', 'opera', 'organic', 'arquitetura', 'architecten', 'arquitectura', 'arquitectos', 'house']
#
#
# Top 10 words for topic #3:
# ['venice', 'participants', '114', 'presentation', 'paolo', 'baratta', 'sarkis', 'hashim', 'howwillwelivetogether', 'biennalearchitettura2020']
#
#
# Top 10 words for topic #4:
# ['creatività', 'del', 'leone', 'comprensivo', 'progetto', 'istituto', 'menzione', 'speciale', 'il', 'biennalecarnevale2020']
#
#
# Top 10 words for topic #5:
# ['world', 'state', 'home', 'park', 'natalie', 'dionne', '2020', 'cabin', 'new', 'architecture']
#
#
# Top 10 words for topic #6:
# ['score', 'lauradern', 'alla', 'continuano', 'presentati', 'joaquinphoenix', 'jokermovie', 'joker', 'venezia76', 'biennalecinema2019']
#
#
# Top 10 words for topic #7:
# ['new', 'garden', 'lab', '10', 'today', 'residential', 'building', 'apartment', 'idin', 'architects']
#
#
# Top 10 words for topic #8:
# ['30', 'center', 'pavilion', 'casa', 'final', 'interior', 'today', 'office', 'design', 'studio']
#
#
# Top 10 words for topic #9:
# ['venezia77', 'da', 'cinema', 'una', 'arquitectos', 'biennale', 'venezia', 'della', 'di', 'la']
#
#
# Top 10 words for topic #10:
# ['medialab', 'seven', 'group', 'join', 'creative', 'led', 'architects', 'learning', 'park', 'centre']

# %%
topic_values = nmf.transform(doc_term_matrix)
tweets_df['Topic'] = topic_values.argmax(axis=1)
tweets_df.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Mon Jan 13 17:45:08 +0000 2020  1216778219636039681  1216778219636039681
# 1  Sat Jan 11 15:45:05 +0000 2020  1216023230575775746  1216023230575775746
# 2  Fri Jan 10 18:40:04 +0000 2020  1215704880708538369  1215704880708538369
# 3  Thu Jan 09 01:17:07 +0000 2020  1215080026116427776  1215080026116427776
# 4  Fri Dec 06 16:35:05 +0000 2019  1202989850351296512  1202989850351296512
#
#                                                 text  truncated  \
# 0    https://t.co/Q7WSVmasnc https://t.co/iMCbG2VfXk      False
# 1    https://t.co/cGodXM8ZJS https://t.co/lHXPIEbKZa      False
# 2    https://t.co/fWGtG511P5 https://t.co/mJhbtITBwT      False
# 3  Want to get rid of vacant storefronts? Let art...       True
# 4                            https://t.co/humao71IWM      False
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                    extended_entities  \
# 0  {'media': [{'id': 1216778217694121984, 'id_str...
# 1  {'media': [{'id': 1216023228684099584, 'id_str...
# 2  {'media': [{'id': 1215704879064322049, 'id_str...
# 3                                                NaN
# 4                                                NaN
#
#                                               source in_reply_to_status_id  \
# 0  <a href="https://www.hootsuite.com" rel="nofol...                  None
# 1  <a href="https://www.hootsuite.com" rel="nofol...                  None
# 2  <a href="https://www.hootsuite.com" rel="nofol...                  None
# 3  <a href="https://www.hootsuite.com" rel="nofol...                  None
# 4  <a href="https://www.hootsuite.com" rel="nofol...                  None
#
#   in_reply_to_status_id_str  ... quoted_status_id quoted_status_id_str  \
# 0                      None  ...     1.214944e+18  1214943608928759809
# 1                      None  ...     1.214982e+18  1214982058818166785
# 2                      None  ...     1.215315e+18  1215315067438170112
# 3                      None  ...              NaN                  NaN
# 4                      None  ...     1.202021e+18  1202020693988249602
#
#                                        quoted_status retweet_count  \
# 0  {'created_at': 'Wed Jan 08 16:15:03 +0000 2020...             2
# 1  {'created_at': 'Wed Jan 08 18:47:50 +0000 2020...             0
# 2  {'created_at': 'Thu Jan 09 16:51:06 +0000 2020...             0
# 3                                                NaN             1
# 4  {'created_at': 'Wed Dec 04 00:24:00 +0000 2019...             0
#
#   favorite_count favorited retweeted possibly_sensitive  lang  Topic
# 0              5     False     False              False   und      0
# 1              6     False     False              False   und      0
# 2              5     False     False              False   und      0
# 3              7     False     False              False    en      4
# 4              2     False     False              False   und      0
#
# [5 rows x 29 columns]

# %%
tweets_df['user'].unique()
# Out:
# array(['mitsap', 'ArchDaily', 'designboom', 'la_Biennale',
#        'MITarchitecture'], dtype=object)

# %%
topic_frequency = tweets_df.groupby(['user','Topic']).size().reset_index().rename(columns={0:'Topic Frequency'})

# %%
topic_frequency.head()
# Out:
#         user  Topic  Topic Frequency
# 0  ArchDaily      0                6
# 1  ArchDaily      1               30
# 2  ArchDaily      2                1
# 3  ArchDaily      3                2
# 4  ArchDaily      4               48

# %%
from bokeh.io import output_notebook
from bokeh.plotting import show, figure
from bokeh.models import ColumnDataSource, LinearColorMapper, ColorBar, BasicTicker, PrintfTickFormatter, HoverTool
from bokeh.palettes import Viridis256
from bokeh.transform import transform
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
d = {'users': topic_frequency['user'].unique()
}

# %%
p = figure(x_range =[-2,11], y_range = topic_frequency['user'].unique())

p.scatter(x = topic_frequency['Topic'], y = topic_frequency['user'], size =topic_frequency['Topic Frequency'])

show(p)
# Out:
#   <div class="bk-root" id="d442ba11-cf28-409a-a0bc-005bc3d58d32" data-root-id="1002"></div>

# %%
import sys
# !{sys.executable} -m spacy download en
import re, numpy as np, pandas as pd
from pprint import pprint

# Gensim
import gensim, spacy, logging, warnings
import gensim.corpora as corpora
from gensim.utils import lemmatize, simple_preprocess
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt

# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use', 'not', 'would', 'say', 'could', '_', 'be', 'know', 'good', 'go', 'get', 'do', 'done', 'try', 'many', 'some', 'nice', 'thank', 'think', 'see', 'rather', 'easy', 'easily', 'lot', 'lack', 'make', 'want', 'seem', 'run', 'need', 'even', 'right', 'line', 'even', 'also', 'may', 'take', 'come'])

# %%
def sent_to_words(sentences):
    for sent in sentences:
        sent = re.sub('\S*@\S*\s?', '', sent)  # remove emails
        sent = re.sub('\s+', ' ', sent)  # remove newline chars
        sent = re.sub("\'", "", sent)  # remove single quotes
        sent = gensim.utils.simple_preprocess(str(sent), deacc=True) 
        yield(sent)  

# Convert to list
data = tweets_df['text'].values.tolist()
data_words = list(sent_to_words(data))
print(data_words[:1])
# Out:
# [['https', 'co', 'wsvmasnc', 'https', 'co', 'imcbg', 'vfxk']]

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# !python3 -m spacy download en  # run in terminal once
# or do
# !conda install -c conda-forge spacy-model-en_core_web_md 
# and use nlp=spacy.load('en_core_web_sm') instead in below function.
def process_words(texts, stop_words=stop_words, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """Remove Stopwords, Form Bigrams, Trigrams and Lemmatization"""
    texts = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]
    texts = [bigram_mod[doc] for doc in texts]
    texts = [trigram_mod[bigram_mod[doc]] for doc in texts]
    texts_out = []
    nlp = spacy.load('en', disable=['parser', 'ner'])
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    # remove stopwords once more after lemmatization
    texts_out = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts_out]    
    return texts_out

data_ready = process_words(data_words)  # processed Text Data!

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_ready)

# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in data_ready]

# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=4, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=10,
                                           passes=10,
                                           alpha='symmetric',
                                           iterations=100,
                                           per_word_topics=True)

pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.026*"design" + 0.021*"architecture" + 0.016*"today" + 0.011*"final" + '
#   '0.010*"lead" + 0.009*"workshop" + 0.008*"pm" + 0.007*"find" + 0.007*"open" '
#   '+ 0.007*"year"'),
#  (1,
#   '0.063*"co" + 0.063*"https" + 0.019*"congratulation" + 0.018*"della" + '
#   '0.010*"material" + 0.010*"award" + 0.006*"leone" + 0.006*"con" + '
#   '0.005*"gli" + 0.005*"art"'),
#  (2,
#   '0.065*"co" + 0.065*"https" + 0.016*"studio" + 0.010*"graduate" + '
#   '0.010*"amp" + 0.010*"la" + 0.009*"student" + 0.009*"live" + 0.005*"venezia" '
#   '+ 0.005*"alumna"'),
#  (3,
#   '0.115*"co" + 0.110*"https" + 0.015*"phd" + 0.015*"review" + '
#   '0.008*"candidate" + 0.007*"edit" + 0.007*"join" + 0.006*"new" + 0.006*"mit" '
#   '+ 0.005*"research"')]

# %%
import seaborn as sns
import matplotlib.colors as mcolors

# %%
from bokeh.plotting import figure, show, output_file
from bokeh.models import ColumnDataSource, Range1d, LabelSet, Label

# Get topic weights
topic_weights = []
for i, row_list in enumerate(lda_model[corpus]):
    topic_weights.append([w for i, w in row_list[0]])

# Array of topic weights    
arr = pd.DataFrame(topic_weights).fillna(0).values

# Keep the well separated points (optional)
arr = arr[np.amax(arr, axis=1) > 0.35]

# Dominant topic number in each doc
topic_num = np.argmax(arr, axis=1)

# tSNE Dimension Reduction
tsne_model = TSNE(n_components=2, verbose=1, random_state=0, angle=.99, init='pca')
tsne_lda = tsne_model.fit_transform(arr)

# Plot the Topic Clusters using Bokeh
output_notebook()
n_topics = 4


colormap = {0: 'red', 1: 'green', 2: 'blue', 3: 'yellow'}

colors = [colormap[x] for x in list(topic_num)]

source = ColumnDataSource(data=dict(x=tsne_lda[:,0],
                                    y=tsne_lda[:,1],
                                    tweets=list(tweets_df['text']),
                                    topic_num=topic_num,
                                    color=colors,
                
                                   ))

TOOLTIPS = [
    ("index", "$index"),
    ("(x,y)", "($x, $y)")
]


mycolors = np.array([color for name, color in mcolors.TABLEAU_COLORS.items()])
plot = figure(title="t-SNE Clustering of {} LDA Topics".format(n_topics), 
              plot_width=900, plot_height=700, background_fill_color = "black")
plot.circle(x='x', y='y', source=source, color='color', tooltips=TOOLTIPS)
plot.axis.visible = False
plot.grid.visible = False
# labels = LabelSet(x='x', y='y', text='tweets', source=source, x_offset=5, y_offset=5)

# plot.add_layout(labels)

show(plot)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 748 samples in 0.001s...
# [t-SNE] Computed neighbors for 748 samples in 0.009s...
# [t-SNE] Computed conditional probabilities for sample 748 / 748
# [t-SNE] Mean sigma: 0.013217
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 51.507687
# [t-SNE] KL divergence after 1000 iterations: 0.239742
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3479">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-114-51f3cb2a004d> in <module>
#      45 plot = figure(title="t-SNE Clustering of {} LDA Topics".format(n_topics),
#      46               plot_width=900, plot_height=700, background_fill_color = "black")
# ---> 47 plot.circle(x='x', y='y', source=source, color='color', tooltips=TOOLTIPS)
#      48 plot.axis.visible = False
#      49 plot.grid.visible = False
#
# fakesource in circle(self, x, y, **kwargs)
#
# ~\Anaconda3\lib\site-packages\bokeh\plotting\helpers.py in func(self, **kwargs)
#     916             mglyph_ca = None
#     917
# --> 918         glyph = _make_glyph(glyphclass, kwargs, glyph_ca)
#     919         nsglyph = _make_glyph(glyphclass, kwargs, nsglyph_ca)
#     920         sglyph = _make_glyph(glyphclass, kwargs, sglyph_ca)
#
# ~\Anaconda3\lib\site-packages\bokeh\plotting\helpers.py in _make_glyph(glyphclass, kws, extra)
#     389     kws = kws.copy()
#     390     kws.update(extra)
# --> 391     return glyphclass(**kws)
#     392
#     393
#
# ~\Anaconda3\lib\site-packages\bokeh\model.py in __init__(self, **kwargs)
#     316         kwargs.pop("id", None)
#     317
# --> 318         super(Model, self).__init__(**kwargs)
#     319         default_theme.apply_to_model(self)
#     320
#
# ~\Anaconda3\lib\site-packages\bokeh\core\has_props.py in __init__(self, **properties)
#     251
#     252         for name, value in properties.items():
# --> 253             setattr(self, name, value)
#     254
#     255     def __setattr__(self, name, value):
#
# ~\Anaconda3\lib\site-packages\bokeh\core\has_props.py in __setattr__(self, name, value)
#     286
#     287             raise AttributeError("unexpected attribute '%s' to %s, %s attributes are %s" %
# --> 288                 (name, self.__class__.__name__, text, nice_join(matches)))
#     289
#     290     def __str__(self):
#
# AttributeError: unexpected attribute 'tooltips' to Circle, possible attributes are angle, angle_units, fill_alpha, fill_color, js_event_callbacks, js_property_callbacks, line_alpha, line_cap, line_color, line_dash, line_dash_offset, line_join, line_width, name, radius, radius_dimension, radius_units, size, subscribed_events, tags, x or y

# %%
tsne_lda[:,0][0]
# Out:
# -22.720804

# %%
list(tweets_df['text'])[0:10]
# Out:
# ['https://t.co/Q7WSVmasnc https://t.co/iMCbG2VfXk',
#  'https://t.co/cGodXM8ZJS https://t.co/lHXPIEbKZa',
#  'https://t.co/fWGtG511P5 https://t.co/mJhbtITBwT',
#  'Want to get rid of vacant storefronts? Let artists take over https://t.co/1J5JEfvMBi @_spaceus @MITarchitecture… https://t.co/6StKI95B7Q',
#  'https://t.co/humao71IWM',
#  'https://t.co/FE5t3NTtjs',
#  'Today at 12:30! https://t.co/EnF3bhPibf',
#  'https://t.co/cirmsAgADK',
#  'Today @ 6pm,  @ACTMIT event: Naeem Mohaiemen, "A Missing Can of Film"—lecture followed by a conversation with Sylvi… https://t.co/FeHfk7T3fh',
#  'https://t.co/ojcbJZzs0B']
