# %%
from twython import Twython
import json

# Load credentials from json file
with open("twitter_credentials.json", "r") as file:
    creds = json.load(file)

# Instantiate an object
twitter = Twython(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'])

# Create our query
query = {'screen_name': 'dchalpern'
        }

# %%
import pandas as pd
returned = {}
# Search tweets
dict_ = {'user': [], 'date': [], 'text': [], 'favorite_count': []}

# %%
twitter.get(endpoint='https://api.twitter.com/1.1/friends/list.json', params={'screen_name':'dchalpern'})
# Out:
# {'users': [{'id': 330568654,
#    'id_str': '330568654',
#    'name': 'katie kowalsky',
#    'screen_name': 'KatieKowalsky',
#    'location': 'San Francisco, CA',
#    'description': 'live. laugh. love sandwiches. cartographer & product witch 🌿🌎✨ she/her',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1812,
#    'friends_count': 714,
#    'listed_count': 80,
#    'created_at': 'Wed Jul 06 20:29:06 +0000 2011',
#    'favourites_count': 28524,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 2835,
#    'lang': None,
#    'status': {'created_at': 'Tue Feb 04 21:55:43 +0000 2020',
#     'id': 1224813812076834816,
#     'id_str': '1224813812076834816',
#     'text': '@lyzidiamond I feel like I’ve been accidentally working towards being a notary all my life',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'lyzidiamond',
#        'name': 'Lyzi Diamond',
#        'id': 17523331,
#        'id_str': '17523331',
#        'indices': [0, 12]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1224811469763727360,
#     'in_reply_to_status_id_str': '1224811469763727360',
#     'in_reply_to_user_id': 17523331,
#     'in_reply_to_user_id_str': '17523331',
#     'in_reply_to_screen_name': 'lyzidiamond',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'ABB8C2',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1204817922008342528/BGiMQ_qD_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1204817922008342528/BGiMQ_qD_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/330568654/1559061599',
#    'profile_link_color': 'C3623A',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'muting': None,
#    'blocking': None,
#    'blocked_by': None,
#    'translator_type': 'none'},
#   {'id': 515691456,
#    'id_str': '515691456',
#    'name': 'Vincent Reina',
#    'screen_name': 'VrainBK',
#    'location': 'Philadelphia, PA',
#    'description': 'Asst Prof @Penn in @penn_planning @PennDesign, focus on urban economics, housing policy, and poverty and inequality. All opinions are my own',
#    'url': 'https://t.co/YxVFOvafXe',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/YxVFOvafXe',
#        'expanded_url': 'http://www.linkedin.com/in/vincentreina',
#        'display_url': 'linkedin.com/in/vincentreina',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 391,
#    'friends_count': 285,
#    'listed_count': 3,
#    'created_at': 'Mon Mar 05 17:44:30 +0000 2012',
#    'favourites_count': 637,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 163,
#    'lang': None,
#    'status': {'created_at': 'Tue Feb 11 16:08:21 +0000 2020',
#     'id': 1227263108944736256,
#     'id_str': '1227263108944736256',
#     'text': "RT @Kate_Howell_Phd: We finally have our own website @RVAEvictionLab! We've added our research briefs and will have frequent blog posts abo…",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'Kate_Howell_Phd',
#        'name': 'Kathryn Howell',
#        'id': 468645381,
#        'id_str': '468645381',
#        'indices': [3, 19]},
#       {'screen_name': 'RVAEvictionLab',
#        'name': 'RVA Eviction Lab',
#        'id': 1020300196805324800,
#        'id_str': '1020300196805324800',
#        'indices': [53, 68]}],
#      'urls': []},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Mon Feb 10 19:52:43 +0000 2020',
#      'id': 1226957186259132416,
#      'id_str': '1226957186259132416',
#      'text': "We finally have our own website @RVAEvictionLab! We've added our research briefs and will have frequent blog posts… https://t.co/R0iFuMKcbC",
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [{'screen_name': 'RVAEvictionLab',
#         'name': 'RVA Eviction Lab',
#         'id': 1020300196805324800,
#         'id_str': '1020300196805324800',
#         'indices': [32, 47]}],
#       'urls': [{'url': 'https://t.co/R0iFuMKcbC',
#         'expanded_url': 'https://twitter.com/i/web/status/1226957186259132416',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [116, 139]}]},
#      'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 17,
#      'favorite_count': 33,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 17,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/969587644622688258/PulAzJaH_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/969587644622688258/PulAzJaH_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/515691456/1520003111',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'muting': None,
#    'blocking': None,
#    'blocked_by': None,
#    'translator_type': 'none'},
#   {'id': 917305795,
#    'id_str': '917305795',
#    'name': 'Emmett McKinney',
#    'screen_name': 'EmmettMcKinney',
#    'location': 'Cambridge, MA',
#    'description': 'MCP 2020 @MITdusp. Passionate about equitable, livable, and sustainable cities, in that order. Plus being outside. 🏘🚲🚊🌳🚶🏽\u200d♂️🌃 Views here my own.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 104,
#    'friends_count': 514,
#    'listed_count': 1,
#    'created_at': 'Wed Oct 31 17:20:48 +0000 2012',
#    'favourites_count': 2154,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 694,
#    'lang': None,
#    'status': {'created_at': 'Mon Feb 10 04:18:57 +0000 2020',
#     'id': 1226722196019699712,
#     'id_str': '1226722196019699712',
#     'text': 'RT @USWNT: Sorry, our allergies acting up again. \n\n@ChristenPress and Papa Press ♥️ https://t.co/6zfggo23as',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'USWNT',
#        'name': 'U.S. Soccer WNT',
#        'id': 133448051,
#        'id_str': '133448051',
#        'indices': [3, 9]},
#       {'screen_name': 'ChristenPress',
#        'name': 'Christen Press',
#        'id': 227879769,
#        'id_str': '227879769',
#        'indices': [51, 65]}],
#      'urls': [],
#      'media': [{'id': 1226680819487408128,
#        'id_str': '1226680819487408128',
#        'indices': [84, 107],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1226680819487408128/pu/img/5GS1o1qvmXElxfBU.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1226680819487408128/pu/img/5GS1o1qvmXElxfBU.jpg',
#        'url': 'https://t.co/6zfggo23as',
#        'display_url': 'pic.twitter.com/6zfggo23as',
#        'expanded_url': 'https://twitter.com/USWNT/status/1226680897874776065/video/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 960, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 1024, 'h': 1280, 'resize': 'fit'}},
#        'source_status_id': 1226680897874776065,
#        'source_status_id_str': '1226680897874776065',
#        'source_user_id': 133448051,
#        'source_user_id_str': '133448051',
#        'features': {}}]},
#     'extended_entities': {'media': [{'id': 1226680819487408128,
#        'id_str': '1226680819487408128',
#        'indices': [84, 107],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1226680819487408128/pu/img/5GS1o1qvmXElxfBU.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1226680819487408128/pu/img/5GS1o1qvmXElxfBU.jpg',
#        'url': 'https://t.co/6zfggo23as',
#        'display_url': 'pic.twitter.com/6zfggo23as',
#        'expanded_url': 'https://twitter.com/USWNT/status/1226680897874776065/video/1',
#        'type': 'video',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 960, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 1024, 'h': 1280, 'resize': 'fit'}},
#        'source_status_id': 1226680897874776065,
#        'source_status_id_str': '1226680897874776065',
#        'source_user_id': 133448051,
#        'source_user_id_str': '133448051',
#        'video_info': {'aspect_ratio': [4, 5],
#         'duration_millis': 32500,
#         'variants': [{'bitrate': 2176000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1226680819487408128/pu/vid/720x900/m4YXkdMmeOGj_cpd.mp4?tag=10'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/1226680819487408128/pu/pl/A7fEEbdUGHkj9Gdd.m3u8?tag=10'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1226680819487408128/pu/vid/360x450/y9bmedoqhASD3SXR.mp4?tag=10'},
#          {'bitrate': 632000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1226680819487408128/pu/vid/320x400/FCOzkUM78oFrvt1p.mp4?tag=10'}]},
#        'features': {},
#        'additional_media_info': {'monetizable': False}}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Mon Feb 10 01:34:51 +0000 2020',
#      'id': 1226680897874776065,
#      'id_str': '1226680897874776065',
#      'text': 'Sorry, our allergies acting up again. \n\n@ChristenPress and Papa Press ♥️ https://t.co/6zfggo23as',
#      'truncated': False,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [{'screen_name': 'ChristenPress',
#         'name': 'Christen Press',
#         'id': 227879769,
#         'id_str': '227879769',
#         'indices': [40, 54]}],
#       'urls': [],
#       'media': [{'id': 1226680819487408128,
#         'id_str': '1226680819487408128',
#         'indices': [73, 96],
#         'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1226680819487408128/pu/img/5GS1o1qvmXElxfBU.jpg',
#         'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1226680819487408128/pu/img/5GS1o1qvmXElxfBU.jpg',
#         'url': 'https://t.co/6zfggo23as',
#         'display_url': 'pic.twitter.com/6zfggo23as',
#         'expanded_url': 'https://twitter.com/USWNT/status/1226680897874776065/video/1',
#         'type': 'photo',
#         'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#          'medium': {'w': 960, 'h': 1200, 'resize': 'fit'},
#          'large': {'w': 1024, 'h': 1280, 'resize': 'fit'}},
#         'features': {}}]},
#      'extended_entities': {'media': [{'id': 1226680819487408128,
#         'id_str': '1226680819487408128',
#         'indices': [73, 96],
#         'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1226680819487408128/pu/img/5GS1o1qvmXElxfBU.jpg',
#         'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1226680819487408128/pu/img/5GS1o1qvmXElxfBU.jpg',
#         'url': 'https://t.co/6zfggo23as',
#         'display_url': 'pic.twitter.com/6zfggo23as',
#         'expanded_url': 'https://twitter.com/USWNT/status/1226680897874776065/video/1',
#         'type': 'video',
#         'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#          'medium': {'w': 960, 'h': 1200, 'resize': 'fit'},
#          'large': {'w': 1024, 'h': 1280, 'resize': 'fit'}},
#         'video_info': {'aspect_ratio': [4, 5],
#          'duration_millis': 32500,
#          'variants': [{'bitrate': 2176000,
#            'content_type': 'video/mp4',
#            'url': 'https://video.twimg.com/ext_tw_video/1226680819487408128/pu/vid/720x900/m4YXkdMmeOGj_cpd.mp4?tag=10'},
#           {'content_type': 'application/x-mpegURL',
#            'url': 'https://video.twimg.com/ext_tw_video/1226680819487408128/pu/pl/A7fEEbdUGHkj9Gdd.m3u8?tag=10'},
#           {'bitrate': 832000,
#            'content_type': 'video/mp4',
#            'url': 'https://video.twimg.com/ext_tw_video/1226680819487408128/pu/vid/360x450/y9bmedoqhASD3SXR.mp4?tag=10'},
#           {'bitrate': 632000,
#            'content_type': 'video/mp4',
#            'url': 'https://video.twimg.com/ext_tw_video/1226680819487408128/pu/vid/320x400/FCOzkUM78oFrvt1p.mp4?tag=10'}]},
#         'features': {},
#         'additional_media_info': {'monetizable': False}}]},
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 2761,
#      'favorite_count': 25262,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 2761,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1024147074806243328/4dA8PK2w_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1024147074806243328/4dA8PK2w_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/917305795/1486096178',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'muting': None,
#    'blocking': None,
#    'blocked_by': None,
#    'translator_type': 'none'},
#   {'id': 17445813,
#    'id_str': '17445813',
#    'name': 'DarkReading',
#    'screen_name': 'DarkReading',
#    'location': 'Manhasset, NY',
#    'description': 'News and information on IT security, helping information security pros manage the balance between data protection and user access.',
#    'url': 'https://t.co/FnUjLnIOWW',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/FnUjLnIOWW',
#        'expanded_url': 'http://www.DarkReading.com',
#        'display_url': 'DarkReading.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 222042,
#    'friends_count': 40,
#    'listed_count': 4760,
#    'created_at': 'Mon Nov 17 17:30:53 +0000 2008',
#    'favourites_count': 697,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 19779,
#    'lang': None,
#    'status': {'created_at': 'Tue Feb 11 21:25:23 +0000 2020',
#     'id': 1227342892991160321,
#     'id_str': '1227342892991160321',
#     'text': 'Microsoft Patches Exploited Internet Explorer Flaw https://t.co/AXMGgJNpk4 by @kellymsheridan \n#Microsoft… https://t.co/4RUtRkVKjZ',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Microsoft', 'indices': [95, 105]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'kellymsheridan',
#        'name': 'Kelly Sheridan',
#        'id': 1483240118,
#        'id_str': '1483240118',
#        'indices': [78, 93]}],
#      'urls': [{'url': 'https://t.co/AXMGgJNpk4',
#        'expanded_url': 'http://ow.ly/a00950yjRr0',
#        'display_url': 'ow.ly/a00950yjRr0',
#        'indices': [51, 74]},
#       {'url': 'https://t.co/4RUtRkVKjZ',
#        'expanded_url': 'https://twitter.com/i/web/status/1227342892991160321',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [107, 130]}]},
#     'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 6,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/885169621795565573/A4mG0U5P_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/885169621795565573/A4mG0U5P_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17445813/1542387020',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'muting': None,
#    'blocking': None,
#    'blocked_by': None,
#    'translator_type': 'none'},
#   {'id': 18888264,
#    'id_str': '18888264',
#    'name': 'VSP',
#    'screen_name': 'v33na',
#    'location': 'CA | DC',
#    'description': '#CTI | Yoga Teacher |@BSidesSac Founder/Co-Director | Chief Wellness Officer @HackersHealth |support @WomenCyberjutsu | @SANSinstitute #PurpleTeamSummit Advisor',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 2061,
#    'friends_count': 1765,
#    'listed_count': 74,
#    'created_at': 'Mon Jan 12 02:28:46 +0000 2009',
#    'favourites_count': 5253,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 3391,
#    'lang': None,
#    'status': {'created_at': 'Mon Feb 10 15:54:30 +0000 2020',
#     'id': 1226897236509982723,
#     'id_str': '1226897236509982723',
#     'text': 'RT @likethecoins: Full indictment: https://t.co/I20TDLPMem',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'likethecoins',
#        'name': 'Katie Nickels',
#        'id': 16240596,
#        'id_str': '16240596',
#        'indices': [3, 16]}],
#      'urls': [{'url': 'https://t.co/I20TDLPMem',
#        'expanded_url': 'https://www.justice.gov/opa/press-release/file/1246891/download',
#        'display_url': 'justice.gov/opa/press-rele…',
#        'indices': [35, 58]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Mon Feb 10 15:34:48 +0000 2020',
#      'id': 1226892278259691527,
#      'id_str': '1226892278259691527',
#      'text': 'Full indictment: https://t.co/I20TDLPMem https://t.co/00ODooedK7',
#      'truncated': False,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/I20TDLPMem',
#         'expanded_url': 'https://www.justice.gov/opa/press-release/file/1246891/download',
#         'display_url': 'justice.gov/opa/press-rele…',
#         'indices': [17, 40]},
#        {'url': 'https://t.co/00ODooedK7',
#         'expanded_url': 'https://twitter.com/AP/status/1226887623941271552',
#         'display_url': 'twitter.com/AP/status/1226…',
#         'indices': [41, 64]}]},
#      'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': True,
#      'quoted_status_id': 1226887623941271552,
#      'quoted_status_id_str': '1226887623941271552',
#      'retweet_count': 18,
#      'favorite_count': 39,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': True,
#     'quoted_status_id': 1226887623941271552,
#     'quoted_status_id_str': '1226887623941271552',
#     'retweet_count': 18,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'DED6C1',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme7/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme7/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/997570861828902913/0Q2Huqqh_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/997570861828902913/0Q2Huqqh_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18888264/1539923789',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'F0E2BE',
#    'profile_sidebar_fill_color': '493443',
#    'profile_text_color': 'F0E2BE',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'muting': None,
#    'blocking': None,
#    'blocked_by': None,
#    'translator_type': 'none'},
#   {'id': 2423861950,
#    'id_str': '2423861950',
#    'name': 'Crystal Lee',
#    'screen_name': 'crystaljjlee',
#    'location': 'Cambridge, MA',
#    'description': 'Writing about tech, power, and disability @MITpsts + @MITvis. I aspire to be the person my dog, Laika, thinks I am. (she/her)',
#    'url': 'https://t.co/zuMog5Rw8c',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/zuMog5Rw8c',
#        'expanded_url': 'http://web.mit.edu/crystall/www/',
#        'display_url': 'web.mit.edu/crystall/www/',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 2149,
#    'friends_count': 3149,
#    'listed_count': 35,
#    'created_at': 'Thu Mar 20 01:35:11 +0000 2014',
#    'favourites_count': 10344,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 3242,
#    'lang': None,
#    'status': {'created_at': 'Tue Feb 11 18:33:15 +0000 2020',
#     'id': 1227299573669998593,
#     'id_str': '1227299573669998593',
#     'text': '@arvindsatya1 OH THANK GOODNESS',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'arvindsatya1',
#        'name': 'Arvind Satyanarayan',
#        'id': 9527212,
#        'id_str': '9527212',
#        'indices': [0, 13]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1227297972368470016,
#     'in_reply_to_status_id_str': '1227297972368470016',
#     'in_reply_to_user_id': 9527212,
#     'in_reply_to_user_id_str': '9527212',
#     'in_reply_to_screen_name': 'arvindsatya1',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1067340289927311360/-GeVWJKA_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1067340289927311360/-GeVWJKA_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2423861950/1497967391',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'muting': None,
#    'blocking': None,
#    'blocked_by': None,
#    'translator_type': 'none'},
#   {'id': 357916553,
#    'id_str': '357916553',
#    'name': 'Shannon Mattern',
#    'screen_name': 'shannonmattern',
#    'location': 'New York, NY',
#    'description': 'faculty @thenewschool. architecture, archives, cities, infrastructure, libraries, maps, sound+. i reserve party politics for other platforms. img: karel martens',
#    'url': 'https://t.co/5ui9t5mp3E',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/5ui9t5mp3E',
#        'expanded_url': 'http://www.wordsinspace.net',
#        'display_url': 'wordsinspace.net',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 13736,
#    'friends_count': 8379,
#    'listed_count': 311,
#    'created_at': 'Fri Aug 19 02:57:32 +0000 2011',
#    'favourites_count': 56056,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 27503,
#    'lang': None,
#    'status': {'created_at': 'Tue Feb 11 21:31:23 +0000 2020',
#     'id': 1227344402902847491,
#     'id_str': '1227344402902847491',
#     'text': '@BuBaykurt Thank you, Burcu!',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'BuBaykurt',
#        'name': 'Burcu Baykurt',
#        'id': 30279765,
#        'id_str': '30279765',
#        'indices': [0, 10]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1227337533241143296,
#     'in_reply_to_status_id_str': '1227337533241143296',
#     'in_reply_to_user_id': 30279765,
#     'in_reply_to_user_id_str': '30279765',
#     'in_reply_to_screen_name': 'BuBaykurt',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'B2DFDA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1185290562120884224/buHldf66_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1185290562120884224/buHldf66_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/357916553/1390800045',
#    'profile_link_color': '93A644',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'FFFFFF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'muting': None,
#    'blocking': None,
#    'blocked_by': None,
#    'translator_type': 'none'},
#   {'id': 579615633,
#    'id_str': '579615633',
#    'name': 'Natalee Desotell',
#    'screen_name': 'nataleedesotell',
#    'location': 'NYC & CT',
#    'description': 'maps + data + epi @icph_homeless @yalesph. \nonce upon a time @uwcartlab @uwmadisongis. \n#firstgen \nshe/they',
#    'url': 'https://t.co/jOSIBnXHaI',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/jOSIBnXHaI',
#        'expanded_url': 'http://nataleedesotell.com',
#        'display_url': 'nataleedesotell.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 878,
#    'friends_count': 2394,
#    'listed_count': 30,
#    'created_at': 'Mon May 14 04:11:38 +0000 2012',
#    'favourites_count': 2751,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 1720,
#    'lang': None,
#    'status': {'created_at': 'Tue Feb 11 19:06:03 +0000 2020',
#     'id': 1227307830253846529,
#     'id_str': '1227307830253846529',
#     'text': '@schaubkatelyn We have a style guide which includes font standards/hex codes to keep things consistent. Everything… https://t.co/tf4CIp5VWb',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'schaubkatelyn',
#        'name': 'Kate Schaub',
#        'id': 1271283517,
#        'id_str': '1271283517',
#        'indices': [0, 14]}],
#      'urls': [{'url': 'https://t.co/tf4CIp5VWb',
#        'expanded_url': 'https://twitter.com/i/web/status/1227307830253846529',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': 1226974395836575749,
#     'in_reply_to_status_id_str': '1226974395836575749',
#     'in_reply_to_user_id': 1271283517,
#     'in_reply_to_user_id_str': '1271283517',
#     'in_reply_to_screen_name': 'schaubkatelyn',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1225083904366989312/lGWk6FZv_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1225083904366989312/lGWk6FZv_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/579615633/1581093216',
#    'profile_link_color': 'FF691F',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'muting': None,
#    'blocking': None,
#    'blocked_by': None,
#    'translator_type': 'none'},
#   {'id': 17448055,
#    'id_str': '17448055',
#    'name': 'Andy Woodruff',
#    'screen_name': 'awoodruff',
#    'location': 'Malden, Massachusetts',
#    'description': 'Cartographer of things. @axismaps + @bostonography + @maptimeBoston. Seen but not heard.',
#    'url': 'https://t.co/MPqwZ7LuQf',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/MPqwZ7LuQf',
#        'expanded_url': 'http://andywoodruff.com',
#        'display_url': 'andywoodruff.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 6159,
#    'friends_count': 551,
#    'listed_count': 357,
#    'created_at': 'Mon Nov 17 19:25:16 +0000 2008',
#    'favourites_count': 934,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 9366,
#    'lang': None,
#    'status': {'created_at': 'Fri Feb 07 17:33:35 +0000 2020',
#     'id': 1225835007207526402,
#     'id_str': '1225835007207526402',
#     'text': "Me: great, each knob will control the burner to which I've connected it\nStove specification: lol no, all knobs cont… https://t.co/BHrORKFI0N",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/BHrORKFI0N',
#        'expanded_url': 'https://twitter.com/i/web/status/1225835007207526402',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': 1225169721064153091,
#     'in_reply_to_status_id_str': '1225169721064153091',
#     'in_reply_to_user_id': 17448055,
#     'in_reply_to_user_id_str': '17448055',
#     'in_reply_to_screen_name': 'awoodruff',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 6,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F2EEEC',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/790513030798807040/x1HMe4s__normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/790513030798807040/x1HMe4s__normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17448055/1418748906',
#    'profile_link_color': '3B94D9',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'muting': None,
#    'blocking': None,
#    'blocked_by': None,
#    'translator_type': 'none'},
#   {'id': 55236002,
#    'id_str': '55236002',
#    'name': 'Mapbox',
#    'screen_name': 'Mapbox',
#    'location': 'Washington DC + San Francisco',
#    'description': 'Mapbox is the location data platform for mobile and web applications. We’re changing the way people move around cities and explore our world.',
#    'url': 'https://t.co/dNEgySRm0u',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/dNEgySRm0u',
#        'expanded_url': 'http://www.mapbox.com/',
#        'display_url': 'mapbox.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 67786,
#    'friends_count': 2075,
#    'listed_count': 2475,
#    'created_at': 'Thu Jul 09 13:34:45 +0000 2009',
#    'favourites_count': 2507,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 11650,
#    'lang': None,
#    'status': {'created_at': 'Tue Feb 11 20:55:03 +0000 2020',
#     'id': 1227335259462799363,
#     'id_str': '1227335259462799363',
#     'text': 'GeoMeetup SF is back! Join us Feb 19 for the first event of 2020. Hear from geo+transit experts and connect with th… https://t.co/ybz3PHyyaS',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ybz3PHyyaS',
#        'expanded_url': 'https://twitter.com/i/web/status/1227335259462799363',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 7,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '1D102D',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1112778715333836801/JDuDUMwe_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1112778715333836801/JDuDUMwe_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/55236002/1565896431',
#    'profile_link_color': '565656',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DCEDFA',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'muting': None,
#    'blocking': None,
#    'blocked_by': None,
#    'translator_type': 'none'},
#   {'id': 2860575512,
#    'id_str': '2860575512',
#    'name': 'Amber J. Bosse',
#    'screen_name': 'mapbosse',
#    'location': 'Boulder, CO',
#    'description': 'NSF Graduate Research Fellow , Ph.D. Candidate, U. of Kentucky Geography. Participatory Action Mapping, Cartographic Efficacy. she/her',
#    'url': 'https://t.co/SOmJpXXVbi',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/SOmJpXXVbi',
#        'expanded_url': 'https://www.mapbosse.com',
#        'display_url': 'mapbosse.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 560,
#    'friends_count': 374,
#    'listed_count': 17,
#    'created_at': 'Fri Oct 17 15:07:01 +0000 2014',
#    'favourites_count': 2446,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 481,
#    'lang': None,
#    'status': {'created_at': 'Wed Feb 05 19:23:24 +0000 2020',
#     'id': 1225137869754269697,
#     'id_str': '1225137869754269697',
#     'text': 'RT @stamen: "Communications Principles for Inviting Inquiry and Exploration Through Science and Data Visualization"  @SICBtweets is now ava…',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'stamen',
#        'name': 'Stamen Design',
#        'id': 2067201,
#        'id_str': '2067201',
#        'indices': [3, 10]},
#       {'screen_name': 'SICBtweets',
#        'name': 'SICB',
#        'id': 882545322,
#        'id_str': '882545322',
#        'indices': [117, 128]}],
#      'urls': []},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Wed Feb 05 18:10:20 +0000 2020',
#      'id': 1225119481040531456,
#      'id_str': '1225119481040531456',
#      'text': '"Communications Principles for Inviting Inquiry and Exploration Through Science and Data Visualization"… https://t.co/bvYz2DQyRI',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/bvYz2DQyRI',
#         'expanded_url': 'https://twitter.com/i/web/status/1225119481040531456',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [105, 128]}]},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 4,
#      'favorite_count': 4,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 4,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/976300733917097984/wnA3GSd1_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/976300733917097984/wnA3GSd1_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2860575512/1531172170',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'muting': None,
#    'blocking': None,
#    'blocked_by': None,
#    'translator_type': 'none'},
#   {'id': 1051171,
#    'id_str': '1051171',
#    'name': 'Ethan Zuckerman',
#    'screen_name': 'EthanZ',
#    'location': 'Pittsfield, MA',
#    'description': 'Center for Civic Media, MIT Media Lab, Global Voices, Berkman Klein Center.  RT ≠ endorsement, RT = interesting read. He/Him #MakeAmericaKindAgain',
#    'url': 'http://t.co/rZpNJ8L8AN',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/rZpNJ8L8AN',
#        'expanded_url': 'http://ethanzuckerman.com/blog',
#        'display_url': 'ethanzuckerman.com/blog',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 55550,
#    'friends_count': 1889,
#    'listed_count': 3235,
#    'created_at': 'Mon Mar 12 23:01:19 +0000 2007',
#    'favourites_count': 14659,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 32830,
#    'lang': None,
#    'status': {'created_at': 'Tue Feb 11 21:02:32 +0000 2020',
#     'id': 1227337144835936257,
#     'id_str': '1227337144835936257',
#     'text': '@sivavaid Nah. My RAs were cool.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'sivavaid',
#        'name': 'SIVA VAIDHYANATHAN🗽🤘🏽',
#        'id': 20406724,
#        'id_str': '20406724',
#        'indices': [0, 9]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1227336768736911368,
#     'in_reply_to_status_id_str': '1227336768736911368',
#     'in_reply_to_user_id': 20406724,
#     'in_reply_to_user_id_str': '20406724',
#     'in_reply_to_screen_name': 'sivavaid',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/659351758704136193/5jUqQnv0_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/659351758704136193/5jUqQnv0_normal.jpg',
# ...
#   {'id': 171259962,
#    'id_str': '171259962',
#    'name': 'Mercedes Bidart',
#    'screen_name': 'mercedesbidart',
#    'location': 'New York, NY',
#    'description': 'De Buenos Aires. Political Science @ubasociales | Master in City Planning @MITdusp | New Economy NYC Mayor’s Office @NYCMWBE | Co-creating @quipumarket',
#    'url': 'https://t.co/4CbxOLzYsy',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/4CbxOLzYsy',
#        'expanded_url': 'http://www.quipumarket.com',
#        'display_url': 'quipumarket.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 845,
#    'friends_count': 1052,
#    'listed_count': 25,
#    'created_at': 'Mon Jul 26 23:18:19 +0000 2010',
#    'favourites_count': 555,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 740,
#    'lang': None,
#    'status': {'created_at': 'Fri Feb 07 00:34:26 +0000 2020',
#     'id': 1225578532203565060,
#     'id_str': '1225578532203565060',
#     'text': 'RT @quipumarket: Dimos comienzo a nuestra colaboración con el @IDB_Lab y @FMSDColombia. Fuimos seleccionados como el primer prototipo del B…',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'quipumarket',
#        'name': 'quipumarket',
#        'id': 1087818184210690049,
#        'id_str': '1087818184210690049',
#        'indices': [3, 15]},
#       {'screen_name': 'IDB_Lab',
#        'name': 'IDB Lab',
#        'id': 95332670,
#        'id_str': '95332670',
#        'indices': [62, 70]},
#       {'screen_name': 'FMSDColombia',
#        'name': 'Fundación Mario Santo Domingo',
#        'id': 582850778,
#        'id_str': '582850778',
#        'indices': [73, 86]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Fri Feb 07 00:33:48 +0000 2020',
#      'id': 1225578369686876160,
#      'id_str': '1225578369686876160',
#      'text': 'Dimos comienzo a nuestra colaboración con el @IDB_Lab y @FMSDColombia. Fuimos seleccionados como el primer prototip… https://t.co/DIr2ZwFkFg',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [{'screen_name': 'IDB_Lab',
#         'name': 'IDB Lab',
#         'id': 95332670,
#         'id_str': '95332670',
#         'indices': [45, 53]},
#        {'screen_name': 'FMSDColombia',
#         'name': 'Fundación Mario Santo Domingo',
#         'id': 582850778,
#         'id_str': '582850778',
#         'indices': [56, 69]}],
#       'urls': [{'url': 'https://t.co/DIr2ZwFkFg',
#         'expanded_url': 'https://twitter.com/i/web/status/1225578369686876160',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': {'id': '0105a80417c159b4',
#       'url': 'https://api.twitter.com/1.1/geo/id/0105a80417c159b4.json',
#       'place_type': 'city',
#       'name': 'Barranquilla',
#       'full_name': 'Barranquilla, Colombia',
#       'country_code': 'CO',
#       'country': 'Colombia',
#       'contained_within': [],
#       'bounding_box': {'type': 'Polygon',
#        'coordinates': [[[-74.9257650027657, 10.8695279953779],
#          [-74.7741010007543, 10.8695279953779],
#          [-74.7741010007543, 11.0466177617921],
#          [-74.9257650027657, 11.0466177617921]]]},
#       'attributes': {}},
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 3,
#      'favorite_count': 11,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'es'},
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'es'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'AED9D0',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1147261796790808578/hC2Q4wiT_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1147261796790808578/hC2Q4wiT_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/171259962/1562363952',
#    'profile_link_color': '038543',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'muting': None,
#    'blocking': None,
#    'blocked_by': None,
#    'translator_type': 'none'},
#   {'id': 1087818184210690049,
#    'id_str': '1087818184210690049',
#    'name': 'quipumarket',
#    'screen_name': 'quipumarket',
#    'location': '',
#    'description': 'Digital community marketplaces for people living from the popular economy in Latin America. We build economic justice, one community at a time.',
#    'url': 'https://t.co/gBPeKyt8aO',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/gBPeKyt8aO',
#        'expanded_url': 'https://www.quipumarket.com/',
#        'display_url': 'quipumarket.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 118,
#    'friends_count': 97,
#    'listed_count': 2,
#    'created_at': 'Tue Jan 22 21:04:00 +0000 2019',
#    'favourites_count': 69,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 85,
#    'lang': None,
#    'status': {'created_at': 'Fri Feb 07 00:33:48 +0000 2020',
#     'id': 1225578369686876160,
#     'id_str': '1225578369686876160',
#     'text': 'Dimos comienzo a nuestra colaboración con el @IDB_Lab y @FMSDColombia. Fuimos seleccionados como el primer prototip… https://t.co/DIr2ZwFkFg',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'IDB_Lab',
#        'name': 'IDB Lab',
#        'id': 95332670,
#        'id_str': '95332670',
#        'indices': [45, 53]},
#       {'screen_name': 'FMSDColombia',
#        'name': 'Fundación Mario Santo Domingo',
#        'id': 582850778,
#        'id_str': '582850778',
#        'indices': [56, 69]}],
#      'urls': [{'url': 'https://t.co/DIr2ZwFkFg',
#        'expanded_url': 'https://twitter.com/i/web/status/1225578369686876160',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': {'id': '0105a80417c159b4',
#      'url': 'https://api.twitter.com/1.1/geo/id/0105a80417c159b4.json',
#      'place_type': 'city',
#      'name': 'Barranquilla',
#      'full_name': 'Barranquilla, Colombia',
#      'country_code': 'CO',
#      'country': 'Colombia',
#      'contained_within': [],
#      'bounding_box': {'type': 'Polygon',
#       'coordinates': [[[-74.9257650027657, 10.8695279953779],
#         [-74.7741010007543, 10.8695279953779],
#         [-74.7741010007543, 11.0466177617921],
#         [-74.9257650027657, 11.0466177617921]]]},
#      'attributes': {}},
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 11,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'es'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1087818306092965895/7mmOm4VB_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1087818306092965895/7mmOm4VB_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1087818184210690049/1563391122',
#    'profile_link_color': '000000',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'muting': None,
#    'blocking': None,
#    'blocked_by': None,
#    'translator_type': 'none'},
#   {'id': 2303751216,
#    'id_str': '2303751216',
#    'name': 'FiveThirtyEight',
#    'screen_name': 'FiveThirtyEight',
#    'location': 'New York, NY',
#    'description': "Data-driven news and analysis from Nate Silver's FiveThirtyEight",
#    'url': 'https://t.co/BDdsHpm7og',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/BDdsHpm7og',
#        'expanded_url': 'http://www.fivethirtyeight.com',
#        'display_url': 'fivethirtyeight.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1091773,
#    'friends_count': 288,
#    'listed_count': 16012,
#    'created_at': 'Tue Jan 21 21:39:32 +0000 2014',
#    'favourites_count': 1219,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 82021,
#    'lang': None,
#    'status': {'created_at': 'Tue Feb 11 20:50:05 +0000 2020',
#     'id': 1227334012127076352,
#     'id_str': '1227334012127076352',
#     'text': 'Our NBA Predictions: https://t.co/4hh55uhYWv',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/4hh55uhYWv',
#        'expanded_url': 'https://53eig.ht/39C8ENB',
#        'display_url': '53eig.ht/39C8ENB',
#        'indices': [21, 44]}]},
#     'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 4,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/875426588061573121/lpQG3W6i_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/875426588061573121/lpQG3W6i_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2303751216/1481815429',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'muting': None,
#    'blocking': None,
#    'blocked_by': None,
#    'translator_type': 'none'},
#   {'id': 2467791,
#    'id_str': '2467791',
#    'name': 'The Washington Post',
#    'screen_name': 'washingtonpost',
#    'location': 'Washington, DC',
#    'description': 'Breaking news, analysis, and opinion. Founded in 1877. Our staff on Twitter: https://t.co/VV0UBAMHg8',
#    'url': 'http://t.co/Hq7hTYkOPg',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/Hq7hTYkOPg',
#        'expanded_url': 'http://washingtonpost.com',
#        'display_url': 'washingtonpost.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'https://t.co/VV0UBAMHg8',
#        'expanded_url': 'https://twitter.com/washingtonpost/lists/washington-post-people',
#        'display_url': 'twitter.com/washingtonpost…',
#        'indices': [77, 100]}]}},
#    'protected': False,
#    'followers_count': 14848223,
#    'friends_count': 1661,
#    'listed_count': 93197,
#    'created_at': 'Tue Mar 27 11:19:39 +0000 2007',
#    'favourites_count': 4471,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 347652,
#    'lang': None,
#    'status': {'created_at': 'Tue Feb 11 21:46:17 +0000 2020',
#     'id': 1227348154733023233,
#     'id_str': '1227348154733023233',
#     'text': 'The viral "broomstick challenge" always works https://t.co/f7TIvlVzjn',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/f7TIvlVzjn',
#        'expanded_url': 'https://wapo.st/2HgY1Dq',
#        'display_url': 'wapo.st/2HgY1Dq',
#        'indices': [46, 69]}]},
#     'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '333333',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1060271522319925257/fJKwJ0r2_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1060271522319925257/fJKwJ0r2_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2467791/1469484132',
#    'profile_link_color': '0057EC',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DBDBDB',
#    'profile_text_color': '323232',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': None,
#    'followed_by': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'muting': None,
#    'blocking': None,
#    'blocked_by': None,
#    'translator_type': 'regular'}],
#  'next_cursor': 1649590942253935453,
#  'next_cursor_str': '1649590942253935453',
#  'previous_cursor': 0,
#  'previous_cursor_str': '0',
#  'total_count': None}

# %%
twitter.get(endpoint='https://api.twitter.com/1.1/friendships/show.json', params={'source_screen_name':'dchalpern', "target_screen_name":'KatieKowalsky'})
# Out:
# {'relationship': {'source': {'id': 805473822,
#    'id_str': '805473822',
#    'screen_name': 'dchalpern',
#    'following': True,
#    'followed_by': False,
#    'live_following': False,
#    'following_received': None,
#    'following_requested': None,
#    'notifications_enabled': None,
#    'can_dm': False,
#    'can_media_tag': None,
#    'blocking': None,
#    'blocked_by': None,
#    'muting': None,
#    'want_retweets': None,
#    'all_replies': None,
#    'marked_spam': None},
#   'target': {'id': 330568654,
#    'id_str': '330568654',
#    'screen_name': 'KatieKowalsky',
#    'following': False,
#    'followed_by': True,
#    'following_received': None,
#    'following_requested': None}}}

# %%
twitter.get(endpoint='https://api.twitter.com/1.1/friends/ids.json', params={'screen_name':'washingtonpost'})
# Out:
# {'ids': [1206978927928979456,
#   261124937,
#   429399439,
#   83505025,
#   25513747,
#   432054515,
#   4562090896,
#   2482948225,
#   181429049,
#   22835289,
#   881761753838665728,
#   42656344,
#   18815447,
#   68738412,
#   618246752,
#   113851780,
#   497653485,
#   218129328,
#   157875409,
#   20611223,
#   24827447,
#   22462270,
#   25702314,
#   21063128,
#   2369960792,
#   19753434,
#   19042788,
#   10877082,
#   2810210762,
#   3447765929,
#   295749907,
#   15777758,
#   245415310,
#   182394467,
#   106721732,
#   1277968200,
#   17036950,
#   29233157,
#   124561405,
#   3284628937,
#   263586455,
#   53157117,
#   394635011,
#   2155528914,
#   72925271,
#   2795677612,
#   24553661,
#   2359377054,
#   1063236495123861506,
#   89537438,
#   334116429,
#   1151723851,
#   39071969,
#   333174260,
#   591282827,
#   575715232,
#   249962999,
#   21331143,
#   460687389,
#   16517419,
#   15463390,
#   2975423277,
#   66732477,
#   330574021,
#   344390233,
#   296932340,
#   423763698,
#   2258994919,
#   230190627,
#   23965221,
#   35910675,
#   18770492,
#   1117102549,
#   19318576,
#   57417461,
#   2281044972,
#   6751212,
#   45952335,
#   100187588,
#   53154009,
#   636989940,
#   19742295,
#   342233158,
#   341367491,
#   480099528,
#   19803225,
#   340452323,
#   535864970,
#   49398113,
#   2359964184,
#   71722711,
#   1465386630,
#   59651402,
#   386135668,
#   47318101,
#   969276824311263232,
#   112806153,
#   56841871,
#   390376290,
#   28982897,
#   1490632248,
#   2790869677,
#   67415806,
#   826052299,
#   342340695,
#   2178485772,
#   101598769,
#   320355081,
#   4843925001,
#   366208429,
#   2809348259,
#   926036936,
#   607777518,
#   407614714,
#   26928948,
#   26613041,
#   816716161954050049,
#   602912840,
#   358122418,
#   513367832,
#   127590906,
#   20292059,
#   16147688,
#   15811429,
#   74041444,
#   3048536865,
#   108088376,
#   35878159,
#   2273505647,
#   3036788467,
#   230856067,
#   16941035,
#   919993611168763904,
#   2534225806,
#   729732158718394369,
#   31636500,
#   739809170,
#   170942226,
#   66476989,
#   273102777,
#   1049586464,
#   76516839,
#   254616847,
#   92854623,
#   2579614256,
#   163919307,
#   1002102536,
#   351133624,
#   23037386,
#   21729897,
#   485264415,
#   856492987,
#   169072915,
#   635569074,
#   1181771305,
#   1026878766449025024,
#   418325508,
#   142771553,
#   508179815,
#   10041792,
#   171811536,
#   14849723,
#   71404417,
#   150786498,
#   227711967,
#   37131364,
#   2825350763,
#   67713651,
#   2773390465,
#   68592951,
#   2376559230,
#   1683928748,
#   14816237,
#   404201296,
#   440297806,
#   525468243,
#   2069111,
#   1075060403007299584,
#   43581352,
#   90407034,
#   2293770588,
#   309714212,
#   348802969,
#   253284469,
#   19232807,
#   20453211,
#   16912204,
#   205251093,
#   2814778367,
#   4327267935,
#   26293838,
#   168290603,
#   28057618,
#   16026783,
#   823415005,
#   918952854,
#   28178127,
#   3262673521,
#   167024520,
#   21440390,
#   379510591,
#   847575078,
#   1508051640,
#   257092272,
#   549524519,
#   305067455,
#   33659353,
#   19934168,
#   37965812,
#   280299519,
#   124804301,
#   17661126,
#   823604576,
#   147666390,
#   75383659,
#   860595301,
#   6578122,
#   16663,
#   1181246658,
#   65349332,
#   138831539,
#   19938640,
#   901654220008546304,
#   18804789,
#   15453670,
#   16133258,
#   19914257,
#   307982591,
#   56845272,
#   927019320,
#   68832423,
#   153216512,
#   322270481,
#   115468758,
#   24260086,
#   731026968,
#   522727519,
#   4008600793,
#   360940947,
#   796169341,
#   37860248,
#   1342121329,
#   51660776,
#   89256736,
#   27323880,
#   1559191434,
#   172705060,
#   404365807,
#   306116656,
#   124111627,
#   81220455,
#   3140043029,
#   27583911,
#   3298843560,
#   21797658,
#   261877537,
#   996057328137973769,
#   36020106,
#   457579721,
#   15139488,
#   41488991,
#   110802477,
#   18390063,
#   2423535042,
#   238854978,
#   2548509690,
#   357721111,
#   29960972,
#   358542647,
#   168318726,
#   58613044,
#   329353102,
#   36967017,
#   267389046,
#   14826802,
#   104259954,
#   19404047,
#   71847547,
#   183898020,
#   26668729,
#   14597239,
#   18623139,
#   383997228,
#   19186003,
#   259800864,
#   256498570,
#   58504135,
#   66492948,
#   257199130,
#   614542142,
#   29367372,
#   1316694738,
#   15220095,
#   33653195,
#   47943177,
#   229506034,
#   196272316,
#   38936142,
#   334385278,
#   18034516,
#   728506592,
#   785399490,
#   28011281,
#   16273144,
#   47589148,
#   14873013,
#   36027595,
#   89043072,
#   1148527908,
#   24730470,
#   80904979,
#   23145378,
#   918130775396175873,
#   222226370,
#   246617130,
#   276514577,
#   59048198,
#   1634066785,
#   49602841,
#   24474468,
#   561516853,
#   19817778,
#   15219854,
#   17446359,
#   21334179,
#   282545479,
#   40982362,
#   39879120,
#   98015030,
#   48144950,
#   16963843,
#   10886522,
#   299448712,
#   18206161,
#   90573676,
#   39000115,
#   46195370,
#   144748652,
#   27696993,
#   28407974,
#   1117836660,
#   56883665,
#   19803365,
#   305141546,
#   37595712,
#   198714937,
#   388472830,
#   17104751,
#   118205135,
#   79366215,
#   24167314,
#   382685028,
#   155784594,
#   3315658770,
#   91386979,
#   4562082869,
#   121019896,
#   1044241,
#   112176708,
#   37759594,
#   6601272,
#   33649897,
#   274038125,
#   181324139,
#   59524045,
#   19929890,
#   21313053,
#   46213956,
#   189726903,
#   3066079354,
#   145869585,
#   14862911,
#   442392652,
#   17910554,
#   15099054,
#   15356079,
#   15691434,
#   26223622,
#   33677014,
#   45511355,
#   111464203,
#   115718513,
#   133875756,
#   15916383,
#   892859169971294212,
#   26016846,
#   37047472,
#   190063585,
#   228256770,
#   34022952,
#   267376187,
#   169545703,
#   236567890,
#   363973702,
#   315331161,
#   185864560,
#   897856607186554880,
#   2405405593,
#   15235581,
#   252764352,
#   169620752,
#   763382314629992448,
#   235664740,
#   257354839,
#   391560579,
#   133343254,
#   143991014,
#   82066670,
#   245217842,
#   304588201,
#   15399512,
#   11670602,
#   211029903,
#   42425980,
#   5336752,
#   23817772,
#   34672717,
#   3030314487,
#   15992753,
#   2565438205,
#   23851283,
#   5412122,
#   540064051,
#   3243082421,
#   2609881874,
#   286428176,
#   846354889819279360,
#   204599219,
#   32576041,
#   842013279090294788,
#   455039820,
#   14133434,
#   30970039,
#   17423992,
#   248884036,
#   19162330,
#   44196397,
#   2228091,
#   27058347,
#   15075999,
#   96152942,
#   738125232,
#   45885775,
#   82749412,
#   1514328961,
#   14639216,
#   1135199568,
#   945158850,
#   474163917,
#   226686893,
#   149669234,
#   107852138,
#   57391774,
#   243751237,
#   169315540,
#   37303498,
#   1169997913,
#   82474899,
#   33919343,
#   425998918,
#   205965649,
#   154571620,
#   391773915,
#   150797735,
#   61267358,
#   248769050,
#   19238400,
#   21764013,
#   38258735,
#   567611029,
#   3700166962,
#   228616511,
#   36764306,
#   735855430589513728,
#   64753254,
#   1970555412,
#   778376924322226176,
#   3161681103,
#   313525999,
#   382008044,
#   702431894,
#   68522205,
#   16956827,
#   146525525,
#   38502248,
#   58390782,
#   180289119,
#   42748507,
#   19377732,
#   47276713,
#   61524775,
#   16248895,
#   15086959,
#   15069454,
#   739853589754093569,
#   4056056338,
#   2499418290,
#   250784170,
#   250323817,
#   460470940,
#   2377401867,
#   182839127,
#   34716314,
#   423924980,
#   243020048,
#   4830540923,
#   581928240,
#   89760116,
#   20849128,
#   26100617,
#   11399802,
#   2361709243,
#   16623443,
#   233050948,
#   128970906,
#   704750550957604864,
#   13734322,
#   110213431,
#   578296285,
#   1471542956,
#   1380810590,
#   37517994,
#   34014022,
#   385778444,
#   2819698697,
#   38769519,
#   391173154,
#   22255006,
#   62889488,
#   1373172403,
#   263493140,
#   227103794,
#   695730757403332609,
#   15506669,
#   21097249,
#   19806595,
#   4854968349,
#   33608239,
#   256053691,
#   119776391,
#   2201398921,
#   337517472,
#   28190205,
#   54943775,
#   21283548,
#   181737941,
#   494414113,
#   43719550,
#   221904033,
#   112224716,
#   4332351760,
#   14191237,
#   223684791,
#   138332821,
#   45984634,
#   36672071,
#   170295901,
#   397542335,
#   92630155,
#   14657786,
#   41250307,
#   18481728,
#   249060131,
#   11388132,
#   3876330618,
#   35785401,
#   2330479255,
#   266271764,
#   2987691297,
#   50325797,
#   80654397,
#   4119741,
#   481456646,
#   62842049,
#   8790772,
#   595299864,
#   494270666,
#   1969426021,
#   364453749,
#   3577737257,
#   154909422,
#   14496660,
#   349394162,
#   34859205,
#   1372270994,
#   260314736,
#   104683629,
#   229633414,
#   14923457,
#   15868551,
#   16253038,
#   16798006,
#   17874756,
#   19875986,
#   22024720,
#   26535379,
#   29383100,
#   32878430,
#   42551022,
#   46447090,
#   54276497,
#   117847329,
#   135558864,
#   144425874,
#   246460967,
#   334897789,
#   2438839411,
#   1638698094,
#   13524182,
#   3243500510,
#   354933574,
#   3086975121,
#   24439201,
#   137468275,
#   22313347,
#   85201778,
#   106520446,
#   100420381,
#   15100219,
#   34330219,
#   59575936,
#   15998509,
#   429583223,
#   3058087529,
#   15914573,
#   54891427,
#   249180181,
#   307469596,
#   10397192,
#   19805527,
#   113504852,
#   57326630,
#   21175250,
#   113125348,
#   246980471,
#   19046500,
#   18290170,
#   56804254,
#   19889946,
#   15027086,
#   362302852,
#   158805689,
#   2216041938,
#   3237221,
#   15912586,
#   17066022,
#   2459609448,
#   17379292,
#   60659498,
#   90774609,
#   326359913,
#   136361303,
#   165505956,
#   44833456,
#   216732063,
#   15264511,
#   2831710385,
#   237889929,
#   180471451,
#   7956982,
#   6318622,
#   49164309,
#   32851339,
#   8215842,
#   17468651,
#   65369238,
#   62850214,
#   92314114,
#   123353734,
#   1849300243,
#   31173062,
#   8452442,
#   18939358,
#   952740715,
#   570158749,
#   14403440,
#   14849562,
#   30645552,
#   188873851,
#   1110404252,
#   306326228,
#   244770087,
#   146157638,
#   209407086,
#   85464101,
#   289029100,
#   368050288,
#   15276573,
#   14787085,
#   185597621,
#   25282846,
#   44986099,
#   48118953,
#   279277338,
#   17350129,
#   52496090,
#   10483142,
#   1639559780,
#   293750778,
#   882832854,
#   233844420,
#   14787577,
#   41882282,
#   174746784,
#   38496530,
#   55993,
#   532894893,
#   446642685,
#   23633703,
#   20177607,
#   309354920,
#   16684243,
#   2518793269,
#   15087011,
#   18812301,
#   78408666,
#   749453,
#   95518830,
#   818925774493405188,
#   78138151,
#   25354366,
#   15635101,
#   150827200,
#   44599480,
#   80628196,
#   18395177,
#   70664371,
#   68498034,
#   17862227,
#   65905779,
#   89563994,
#   14871546,
#   75797367,
#   1020058453,
#   162473641,
#   26533046,
#   119199684,
#   950531,
#   2450619818,
#   12727,
#   604949797,
#   47786101,
#   38035476,
#   106198120,
#   255882510,
#   15577108,
#   16552388,
#   14736892,
#   40055348,
#   39335089,
#   23731537,
#   313091751,
#   550010708,
#   54682125,
#   20309840,
#   90786626,
#   39308549,
#   15949696,
#   16544024,
#   22795270,
#   17348525,
#   21780652,
#   126424795,
#   26522141,
#   75936862,
#   2303751216,
#   44317593,
#   241682176,
#   16075694,
#   902816209,
#   2375990671,
#   116028519,
#   14345812,
#   14766917,
#   600580312,
#   17677955,
#   65260792,
#   494287469,
#   348662319,
#   19464906,
#   19299909,
#   17174089,
#   103927659,
#   329873500,
#   30468350,
#   17759597,
#   2329066872,
#   429707461,
#   44958738,
#   250302118,
#   98106155,
#   449588356,
#   11348282,
#   94169802,
#   16288269,
#   57741304,
#   452521774,
#   14348157,
#   2255182597,
#   24112504,
#   250678684,
#   16906374,
#   114229053,
#   93789657,
#   472158763,
#   21612942,
#   422293154,
#   1316672252,
#   226376452,
#   1330457336,
#   2174393299,
#   22529427,
#   18805224,
#   353225544,
#   369224473,
#   1630896181,
#   813286,
#   749963,
#   17340781,
#   58524428,
#   116820849,
#   32433037,
#   130157956,
#   22428641,
#   16129920,
#   475988505,
#   97946098,
#   20608910,
#   166002047,
#   15816595,
#   24730891,
#   1944851868,
#   15210284,
#   539965863,
#   594949605,
#   198381553,
#   183802609,
#   757303975,
#   116775999,
#   5695032,
#   39114551,
#   46696817,
#   38142665,
#   24164338,
#   52554306,
#   131977300,
#   73473531,
#   15738599,
#   115749048,
#   593893034,
#   16312576,
#   43254421,
#   211643692,
#   451586190,
#   16031927,
#   34615731,
#   26930438,
#   16104258,
#   26886095,
#   369232105,
#   1603381488,
#   304612181,
#   307259829,
#   1967216306,
#   1411434049,
#   1921350434,
#   151998296,
#   182876615,
#   60024268,
#   17241749,
#   41814169,
#   186583544,
#   774449653,
#   114327049,
#   86129724,
#   1230979592,
#   46309783,
#   339851087,
#   65535700,
#   19471123,
#   26007752,
#   9720702,
#   294754068,
#   23621827,
#   1707321486,
#   17473643,
#   1101780086,
#   22816767,
#   783214,
#   171643751,
#   176684677,
#   1585964245,
#   372862603,
#   422737714,
#   8568612,
#   380648579,
#   93240602,
#   424455957,
#   55030162,
#   221171155,
#   17310228,
#   5746402,
#   82167518,
#   14326420,
#   346605991,
#   116630713,
#   16480563,
#   966638065,
#   6385432,
#   17018840,
#   14173315,
#   1571270053,
#   233842454,
#   242836537,
#   476256944,
#   250188760,
#   44681022,
#   14700316,
#   31187221,
#   76348185,
#   20793816,
#   15740818,
#   16635362,
#   19993635,
#   23092890,
#   40152529,
#   7309052,
#   19380829,
#   356885109,
#   18891923,
#   14335880,
#   14615871,
#   1530850933,
#   61270808,
#   38254095,
#   1122192223,
#   15996830,
#   78406420,
#   13194,
#   16076032,
#   1522468057,
#   1522464770,
#   17137891,
#   96780563,
#   39527404,
#   1522906376,
#   15573613,
#   161023696,
#   169586280,
#   15652540,
#   564735028,
#   340613443,
#   36934173,
#   224349647,
#   16102460,
#   47399805,
#   16045981,
#   320938715,
#   14159148,
#   44513878,
#   19084128,
#   355906128,
#   116496709,
#   993972252,
#   458287908,
#   543733563,
#   220009727,
#   41129876,
#   211950466,
#   274743702,
#   29455548,
#   155990453,
#   140964944,
#   44123487,
#   21701757,
#   15647676,
#   120176950,
#   27697869,
#   41655821,
#   551197791,
#   792449084,
#   14677751,
#   30231097,
#   20086360,
#   5694822,
#   36972997,
#   584139171,
#   21572351,
#   20747881,
#   18938912,
#   15765991,
#   117543420,
#   21518962,
#   14165170,
#   997684836,
#   133751142,
#   228403233,
#   6680762,
#   6812162,
#   14142441,
#   ...],
#  'next_cursor': 0,
#  'next_cursor_str': '0',
#  'previous_cursor': 0,
#  'previous_cursor_str': '0',
#  'total_count': None}

# %%
returned = twitter.get(endpoint='https://api.twitter.com/1.1/statuses/user_timeline.json', params={'screen_name':'washingtonpost','count':200, 'exclude_replies':True, 'include_rts':False})

# %%
text_block = ""
for entry in returned:
    text_block+= f"{entry['text']} "

# %%
text_block
# Out:
# 'Breaking: All four prosecutors in Roger Stone’s case have asked to withdraw, raising questions about politicization… https://t.co/c84kcIJGl6 Prince George’s officer accused of shooting of handcuffed man fighting a murder charge https://t.co/ae0bJvNNv3 Opinion: Klobuchar’s friends tell a different story about her https://t.co/4wd6hEwRcp For China’s leaders, pop-up hospitals are about politics as much as health https://t.co/0llYnsZTA4 Denver just ended its 30-year ban on pit bulls https://t.co/Utgvmwd2sq A child-welfare worker came to pick up a second-grader. The school handed over the wrong student. https://t.co/SLz5msEiBs The viral "broomstick challenge" always works https://t.co/f7TIvlVzjn U.S.-Mexico border crossings continue to drop, but Mexican migrants surging https://t.co/QdQaCZU4Xo American Airlines extends China flight cancellations through April https://t.co/cD1dks0NqN Fall back in love with Valentine’s Day by breaking out of your dinner-and-flowers rut https://t.co/ZlRC3X8Y5F Venezuelan opposition leader Guaidó braces for confrontation, challenges as he returns to Caracas https://t.co/Baaoirx3sC Former member of Robert Mueller\'s team seeks to quit Roger Stone\'s case amid fight with superiors over the Trump al… https://t.co/ZRO8aYPX3c Analysis: The Justice Department makes yet another suspiciously pro-Trump move in Russia probe https://t.co/qobV7O6x88 Samsung’s new phones bring 100-times zoom, folding screens — and way higher prices https://t.co/MNcoiYeBSt "Before I offer romantic advice to strangers on the Internet, I should probably disclose that I once wrote an entir… https://t.co/URZY8yHUZZ Analysis: The Biden campaign has enormous momentum — in the wrong direction https://t.co/7yZLp3tMT0 Opinion: Can America safeguard the vote? https://t.co/JJhgFJAPi6 The District’s economy is booming, but many black Washingtonians have been left out, study finds https://t.co/c9r94Fe43m Hotel Bibles are still a thing.\n\nBut for some brands, they’re on their way out. https://t.co/FX8pcfvwkq Leaders in El Salvador and across Latin America leaning on the military to assert power https://t.co/Q4MCaDDFMR For decades, countries all over the world trusted a single company to keep the communications of their spies, soldi… https://t.co/TOYOdQ6pJt Federal prosecutors question "integrity and competence" of D.C. crime lab https://t.co/prSjFXwdQF Review: The juicy details of Jessica Simpson’s memoir are only part of her misunderstood story https://t.co/mabBtwzIru Perspective: Both Republicans and Democrats hate the establishment, but they hate very different things https://t.co/zXAyeXcZx0 Analysis: And then there were four: "Bachelor" Peter Weber picks his hometown dates https://t.co/Ox8MDPTVM3 New Hampshire primary live updates: Candidates make last stops as voters weigh in https://t.co/ElAhoZ2mRU Opinion: Calm down.\n\nDemocrats are not in disarray. https://t.co/8F14xkQpaz At least 15 Rohingya refugees drown after boat sinks in Bay of Bengal https://t.co/SVkgNV8EpW Deluge floods Sydney with the heaviest rain since 1990, dousing bush fires as Cyclone Uesi nears https://t.co/3uzsAE9ftO Analysis: Bernie Sanders banks on youth vote turnout in New Hampshire https://t.co/Xe7tVkPiQ0 Analysis: Trump isn’t worried about beating Republicans in the primaries.\n\nHe wants to beat the Democrats. https://t.co/InYc324sOv Justice Dept. to reduce Roger Stone\'s sentencing recommendation, official says, after Trump calls it \'unfair\' https://t.co/zXXa2hzBwp The new MLB playoff proposal has its pluses and minuses.\n\nSupporters say it gives more teams a chance. Detractors s… https://t.co/GAO1vc07eX Opinion: Democrats might be undecided for a long time https://t.co/nJLfLMMSBa Analysis: Trump’s approach to crime and punishment is centered on his own power https://t.co/qFJygHiYP4 Lit up by the 2017 Astros, he never pitched in MLB again. Now he’s suing. https://t.co/PA7ogGf5n6 Arsonist pleads guilty to torching three black churches to "raise his profile as a ...

# %%
import os

from os import path
from wordcloud import WordCloud

# Read the whole text.
text = text_block

# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
text_block = ""
followers_list = ['mitsap','ArchDaily','designboom','la_Biennale','MITarchitecture']
for follower in followers_list:
    print(follower)
    returned = twitter.get(endpoint='https://api.twitter.com/1.1/statuses/user_timeline.json', params={'screen_name':follower,'count':200, 'exclude_replies':True, 'include_rts':False})
    print(len(returned))
    print(len(text_block))
    for entry in returned:
        text_block+= f"{entry['text']} "
# Out:
# mitsap
# 102
# 0
# ArchDaily
# 200
# 9624
# designboom
# 199
# 25861
# la_Biennale
# 188
# 51205
# MITarchitecture
# 65
# 75650

# %%
import os

from os import path
from wordcloud import WordCloud

# Read the whole text.
text = text_block2

# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from textblob import TextBlob
import nltk
nltk.download('brown')
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\cello\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\cello\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\cello\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re

text_block = re.sub("https", " ",  text_block)

# %%
words_list = text_block.split()
text_block2 = ""
for word in words_list:
    if ((word[0:3]=='://') or (word=="https") or (word in stopwords)):
        continue
    elif (word[0:1]=="#"):
        text_block2+=f"{word[1:]}"
    elif (len(word)<4):
        pass
    else:
        text_block2+=f"{word} "
text_block2 = re.sub("@", "",  text_block2)
text_block2 = re.sub("amp", "",  text_block2)
text_block2 = re.sub(",", "",  text_block2)
text_block2 = re.sub("&", " ",  text_block2)
text_block2 = re.sub(":", " ",  text_block2)
text_block2 = re.sub("’", " ",  text_block2)
text_block2 = re.sub("'", " ",  text_block2)
text_block2 = re.sub("``", " ",  text_block2)

# %%
text_block2
# Out:
# 'Want vacant storefronts? artists take _spaceus MITarchitecture… Today 12 30! Today 6pm ACTMIT event  Naeem Mohaiemen Missing Film"—lecture followed conversation Sylvi… Your weekly five SA+P  News resources events School community. Collier Memorial AIANational s 2019 Innovation Award winner. Congratulations former MITarchitecture… Learn admissions programs school culture research architecture upcoming online info… weekly five SA+P  News resources events School community. Today Starting 6pm! Student Q ;A Panel Live Stream MITCRE in-depth view life MSRED student!… Congratulations medialab s Danielle Wood recently inducted International Academy Astronautics… Today 2pm! Carl D Apolito-Dworkin Yushiro Okamoto  Case Studies DS+R Preston Scott Cohen Architects… Your weekly five SA+P  news resources events more. Tomorrow 5 30pm Keller Gallery opening reception Cristina Parreño Alonso  Transtectonics.… Tomorrow 6pm MITarchitecture fall lecture series  "Conversations Care" Beatrice Galilee Miljački… 10/22 6pm wesleyan_u s Jennifer Tucker discusses "Dangerous Exposures  Work Waste Victorian Photograph… ArtsatMIT  Alicja Kwade  Between Glances featured BostonGlobe s "New England s fascinating museum Paradiso medialab created world s largest modular synthesizer—by hand. Learn about… "Life lately surreal complex circular." medialab alumna qijie tweets work John Blakinger OxfordArtHist discusses mitpress book Gyorgy Kepes—a look MITCAVSfounder s… It s last weekend ACTMIT Professor Emerita Joan Jonas s exhibit drawings Know They Left (clos… Architect Matthew Herman burohappold Chicago guest MITarchitecture s Building Technology Group Mond… medialab  Learning Creative Learning back! Lifelong Kindergarten group join community educators… ACT s Azra Akšamija speak “#swisstouch Presents  Heritage Peril–Alternative Approaches Preservation”… “We re looking various components makes city green also critical serves… Learn design innovation entrepreneurship mitdesignx Innovation Housing Venture Workshop Join MITLCAU Leventhal Prize winner Malden Works public kick-off event 10/21. MysticMyRWA MaldenWorks…weekly five SA+P  News resources events School community. weekly five SA+P  News resources events School community. Applications MITdesignX2020 cohort open! mitstudents learn apply November weekly five SA+P  News resources events School community. Deploying drones prepare climate change. MITarchitecture candidate mitdesignx alumna Norhan Bayomi… Making extraordinary norm. MITdusp s Gabriella Carolini named Committed Caring graduate student… weekly five SA+P  News resources events School community. Making impact textile systems. "T-Serai  Portable Palace Transcultural Futures" textile ins… weekly five SA+P  News resources events School community. historian modernity MITarchitecture s hyde_timothy explores relationship architecture socie… weekly five SA+P  News resources events School community. Executive Board International Monetary Fund (IMFNews) appointed MITDUSP SPURS alumna Kristalina Making impact textile systems. "T-Serai  Portable Palace Transcultural Futures" textile ins… weekly five SA+P  News resources events School community. weekly five SA+P  News resources events School community. weekly five SA+P  News resources events School community. weekly five SA+P  News resources events School community. Building Bridges. MITarchitecture s Caitlin Mueller profiled machine learning support des… historian modernity MITarchitecture s hyde_timothy explores relationship architecture socie… weekly five SA+P  News resources events School community. ICYMI Have seen SA+P s thesis website featuring projects "2019 SA+P Thesis Show"? Explore work… Labor Intensive. MITdusp s JasonBJackson serves MIT s Task Force Work Future effort under… weekly five SA+P  News resources events School community. Towards musics  What future holds sound creativity. operafuture s todopera CharlesHolbrow discus… website features projects "2019 SA+P Thesis Show" currently view Gallery Vi ...

# %%
import nltk
from nltk import word_tokenize
from nltk.util import ngrams
from collections import Counter

token = nltk.word_tokenize(text_block2)
bigrams = ngrams(token,2)
print(Counter(bigrams))
# Out:
# Counter({('five', 'SA+P'): 18, ('resources', 'events'): 18, ('weekly', 'five'): 17, ('SA+P', 'News'): 17, ('News', 'resources'): 17, ('events', 'School'): 17, ('School', 'community'): 17, ('community', '.'): 17, ('Architettura', 'arte'): 10, ('all', 'Istituto'): 8, ('BiennaleCarnevale2020Menzione', 'speciale'): 8, ('Biennale', 'Venezia'): 8, ('arte', 'dialogo'): 8, ('dialogo', 'discipline'): 8, ('MITarchitecture', 's'): 7, ('Istituto', 'Comprensivo'): 7, ('della', 'Biennale'): 7, ('world', 's'): 6, ('.', 'weekly'): 6, ('d', 'Argento'): 6, ('speciale', 'all'): 6, ('“', 'Architettura'): 6, ('designindaba', '2020'): 5, ('2020', 'explores'): 5, ('explores', 'design'): 5, ('design', 'change'): 5, ('change', 'future'): 5, ('future', '25th'): 5, ('25th', 'anniversary'): 5, ('anniversary', 'edition'): 5, ('hotel', 'bali'): 5, ('saluto', 'commosso'): 5, ('Argento', 'Creatività'): 5, ('discipline', '”'): 5, ('!', '…'): 4, ('.', 'MITarchitecture'): 4, ('architecture', ';'): 4, ('gt', ';'): 4, ('architects', 'completes'): 4, ('shipping', 'containers'): 4, ('alberto', 'meda'): 4, ('restaurant', 'vietnam'): 4, ('architects', 'builds'): 4, ('Leone', 'd'): 4, ('d', 'Oro'): 4, ('!', "''"): 4, ('EARLY', 'BIRD'): 4, ('``', 'Architettura'): 4, ('Thresholds', 'Repeat'): 4, ('Walker', 'Downey'): 4, ('!', '!'): 4, ('s', 'largest'): 3, ('.', "''"): 3, ('Building', 'Technology'): 3, ('.', 'MITdusp'): 3, ('MITdusp', 's'): 3, ('historian', 'modernity'): 3, ('modernity', 'MITarchitecture'): 3, ('s', 'hyde_timothy'): 3, ('hyde_timothy', 'explores'): 3, ('explores', 'relationship'): 3, ('relationship', 'architecture'): 3, ('architecture', 'socie…'): 3, ('socie…', 'weekly'): 3, ('projects', '``'): 3, ('``', '2019'): 3, ('2019', 'SA+P'): 3, ('SA+P', 'Thesis'): 3, ('Thesis', 'Show'): 3, ('Show', "''"): 3, ('MIT', 's'): 3, ('Cultural', 'Center'): 3, ('Design', 'Studio'): 3, ('TOOP', 'architectuur'): 3, ('s', 'first'): 3, ('studio', 'madrid'): 3, ('madrid', 'suspended'): 3, ('suspended', 'ceiling'): 3, ('kuramoto', 's'): 3, ('s', 'maki'): 3, ('maki', 'chair'): 3, ('entry', 'portals'): 3, ('completes', 'first'): 3, ('first', 'hotel'): 3, ('bali', 'conceived'): 3, ('conceived', 'public'): 3, ('public', 'space'): 3, ('foldable', 'smartphone'): 3, (')', 'progetto'): 3, ('progetto', '“'): 3, ('BiennaleCarnevale2020Leone', 'd'): 3, ('Creatività', 'all'): 3, ('Comprensivo', '“'): 3, ('”', 'Scuola'): 3, ('sede', 'della'): 3, ('year', 'Architecture'): 3, ('Architecture', 'Cinema'): 3, ('Cinema', 'Dance'): 3, ('Dance', 'Theatre'): 3, ('Theatre', 'Music'): 3, ('Music', 'support'): 3, ('support', 'activities'): 3, ('anno', 'Architettura'): 3, ('Architettura', 'Cinema'): 3, ('Cinema', 'Danza'): 3, ('Danza', 'Teatro'): 3, ('Teatro', 'Musica'): 3, ('Musica', 'sostieni'): 3, ('sostieni', 'attività'): 3, ('attività', 'della'): 3, ('“', 'All'): 3, ('portare', 'scena'): 3, ('bando', 'della'): 3, ('discipline', 'Michelangelo'): 3, ('Michelangelo', 'Luigi'): 3, ('(', 'SMArchS'): 3, ('(', 'PhD'): 3, ('Debora', 'Mesa'): 3, ('``', 'What'): 3, ('Repeat', 'edited'): 3, ('Final', 'review'): 3, ('Your', 'weekly'): 2, ('…', 'Congratulations'): 2, ('medialab', 's'): 2, ('It', 's'): 2, ('back', '!'): 2, ('“', '#'): 2, ('Making', 'impact'): 2, ('impact', 'textile'): 2, ('textile', 'systems'): 2, ('systems', '.'): 2, ('.', '``'): 2, ('``', 'T-Serai'): 2, ('T-Serai', 'Portable'): 2, ('Portable', 'Palace'): 2, ('Palace', 'Transcultural'): 2, ('Transcultural', 'Futures'): 2, ('Futures', "''"): 2, ("''", 'textile'): 2, ('textile', 'ins…'): 2, ('ins…', 'weekly'): 2, ('Building', 'Bridges'): 2, ('Bridges', '.'): 2, ('s', 'Caitlin'): 2, ('Caitlin', 'Mueller'): 2, ('Mueller', 'profiled'): 2, ('SA+P', 's'): 2, ('s', 'thesis'): 2, ('Labor', 'Intensive'): 2, ('Intensive', '.'): 2, ('s', 'JasonBJackson'): 2, ('JasonBJackson', 'serves'): 2, ('serves', 'MIT'): 2, ('s', 'Task'): 2, ('Task', 'Force'): 2, ('Force', 'Work'): 2, ('Work', 'Future'): 2, ('Future', 'effort'): 2, ('effort', 'under…'): 2, ('website', ...

# %%
print(Counter(bigrams))
# Out:
# Counter()
